# %%
from damage import run_test_case2

# %% [markdown]
# # 无章和贤者之证测试

# %%
run_test_case2(
    title="基础数学验证 (无概率)",
    description="验证基础伤害扣减和回合数计算是否准确 (预期伤害 40)。",
    sim_params={
        'm_hp': 100, 'm_atk': 20, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 30, 'h_def': 10, 'h_eva': 0, 'h_crit': 0,
        'abnormal_prob': 0.678
    }
)
 
run_test_case2(
    title="临界值 1点伤害测试",
    description="勇士不破防，但达到攻击临界值，造成强制1点伤害。",
    sim_params={
        'm_hp': 5, 'm_atk': 100, 'm_def': 50, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 50, 'h_def': 0, 'h_eva': 0, 'h_crit': 0,
        'h_atk_thresh': 5,
        'abnormal_prob': 0.123
    }
)
 
run_test_case2(
    title="坚固怪物 (Solid) + 50% 暴击",
    description="怪物防御自动调整为勇士攻击力，依赖临界值和暴击输出。",
    sim_params={
        'm_hp': 15, 'm_atk': 50, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 100, 'h_def': 40, 'h_eva': 0, 'h_crit': 0.5,
        'h_atk_thresh': 10, 'special_type': 'solid',
        'abnormal_prob': 0.901
    },
    n_trials=50000 
)
 
run_test_case2(
    title="魔攻怪物 (Magic) + 50% 闪避",
    description="勇士防御极高但被魔攻无视，依靠50%闪避减少伤害。",
    sim_params={
        'm_hp': 100, 'm_atk': 50, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 35, 'h_def': 1000, 'h_eva': 0.5, 'h_crit': 0,
        'special_type': 'magic',
        'abnormal_prob': 0.345
    }
)
 
run_test_case2(
    title="3连击怪物 (K-Combo)",
    description="怪物每回合攻击3次，测试高频攻击下的伤害累积。",
    sim_params={
        'm_hp': 200, 'm_atk': 20, 'm_def': 0, 'm_eva': 0.1, 'm_crit': 0.2,
        'h_atk': 30, 'h_def': 10, 'h_eva': 0.1, 'h_crit': 0.3,
        'special_type': 'k_combo', 'k_value': 3,
        'abnormal_prob': 0.567
    }
)
 
run_test_case2(
    title="仿攻怪物 (Mimic)",
    description="怪物攻击力复制勇士攻击力，造成巨额伤害。",
    sim_params={
        'm_hp': 500, 'm_atk': 10, 'm_def': 100, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 200, 'h_def': 50, 'h_eva': 0, 'h_crit': 0,
        'special_type': 'mimic',
        'abnormal_prob': 0.888
    }
)
 
run_test_case2(
    title="无法击败测试 (NaN)",
    description="勇士攻击力不足且未达临界值，预期返回 NaN。",
    sim_params={
        'm_hp': 100, 'm_atk': 10, 'm_def': 100, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 10, 'h_def': 10, 'h_eva': 0, 'h_crit': 0,
        'h_atk_thresh': 0,
        'abnormal_prob': 0.034,
        'emblem_type': 'sage', 'emblem_level': 3
    },
    n_trials=100
)
# Out:
# ...
# 测试案例: 基础数学验证 (无概率)
# 描述: 验证基础伤害扣减和回合数计算是否准确 (预期伤害 40)。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 20
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 30
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# 【异常状态概率】: 0.678
# ------------------------------------------------------------
# 【公式预期】: 0.9892
# 【模拟频率】: 0.9895
# 【误差分析】: 误差 0.0002
# ------------------------------
# 【蒙特卡洛模拟异常状态统计结果】
# 模拟次数     : 20000
# 异常状态次数 : 19789
# 异常状态频率 : 0.9895
# ------------------------------
# ...
# 测试案例: 临界值 1点伤害测试
# 描述: 勇士不破防，但达到攻击临界值，造成强制1点伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 5
#   攻击力(ATK): 100
#   防御力(DEF): 50
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 0
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 5, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# 【异常状态概率】: 0.123
# ...

# %% [markdown]
# ## 无章和贤者之证含有秒杀的测试

# %%
# ====== 贤者之证 1级 补充测试 ======
run_test_case2(
    title="贤者1级-补充-零伤固防",
    description="贤者1级 + 坚固：勇士防御极高，结合集能减伤50点，使怪物伤害为0。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.2, # 极高防御
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 1,
        'abnormal_prob': 0.15 # 手动指定值
    }
)

run_test_case2(
    title="贤者1级-补充-零伤多击",
    description="贤者1级 + K连击(k=2)：勇士防御极高，保证怪物每次连击伤害均为0。",
    sim_params={
        'm_hp': 1500, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.18, # 极高防御
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'sage', 'emblem_level': 1,
        'abnormal_prob': 0.22 # 手动指定值
    }
)

# ====== 贤者之证 2级 补充测试 ======
run_test_case2(
    title="贤者2级-补充-零伤仿攻",
    description="贤者2级 + 仿攻：勇士高防 + 集能减伤100点，应对仿攻的低基攻。",
    sim_params={
        'm_hp': 8000, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.1, # 极高防御
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 2,
        'abnormal_prob': 0.38 # 手动指定值
    }
)

run_test_case2(
    title="贤者2级-补充-零伤高攻",
    description="贤者2级：集能减伤100点，配合闪避和防御，抵消较高攻击力的怪物。",
    sim_params={
        'm_hp': 1200, 'm_atk': 120, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 250, 'h_eva': 0.3, 'h_crit': 0.15,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'sage', 'emblem_level': 2,
        'abnormal_prob': 0.11 # 手动指定值
    }
)

# ====== 贤者之证 3级 补充测试 ======
run_test_case2(
    title="贤者3级-补充-零伤连击",
    description="贤者3级 + K连击(k=4)：100%闪避确保怪物无法命中，集能减伤100为理论零伤提供支持。",
    sim_params={
        'm_hp': 1500, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 150, 'h_eva': 0.35, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'sage', 'emblem_level': 3,
        'abnormal_prob': 0.30 # 手动指定值
    }
)

run_test_case2(
    title="贤者3级-补充-零伤极限高攻",
    description="贤者3级：100%闪避直接判定为零伤害，但仍验证集能减伤100对高攻的保障。",
    sim_params={
        'm_hp': 2000, 'm_atk': 500, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 550, 'h_def': 2500, 'h_eva': 0.45, 'h_crit': 0.15,
        'emblem_type': 'sage', 'emblem_level': 3,
        'abnormal_prob': 0.40 # 手动指定值
    }
)
# Out:
# ...
# 测试案例: 贤者1级-补充-零伤固防
# 描述: 贤者1级 + 坚固：勇士防御极高，结合集能减伤50点，使怪物伤害为0。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 1)
# 【异常状态概率】: 0.15
# ------------------------------------------------------------
# 【公式预期】: 1.0000
# 【模拟频率】: 1.0000
# 【误差分析】: 误差 0.0000
# ------------------------------
# 【蒙特卡洛模拟异常状态统计结果】
# 模拟次数     : 20000
# 异常状态次数 : 20000
# 异常状态频率 : 1.0000
# ------------------------------
# ...
# 测试案例: 贤者1级-补充-零伤多击
# 描述: 贤者1级 + K连击(k=2)：勇士防御极高，保证怪物每次连击伤害均为0。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# ...

# %% [markdown]
# # 霸者之证测试

# %%
# ====== 霸者之证 1级 测试 ======
run_test_case2(
    title="霸者1级-普通怪物",
    description="霸者1级：反弹概率6%，无霸体。测试基础反弹机制。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 1,
        'abnormal_prob': 0.231
    }
)

run_test_case2(
    title="霸者1级-坚固怪物(Solid)",
    description="霸者1级 + 坚固怪物：测试反弹与坚固属性交互。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 1,
        'abnormal_prob': 0.450
    }
)

run_test_case2(
    title="霸者1级-仿攻怪物(Mimic)",
    description="霸者1级 + 仿攻：怪物攻击被复制，反弹伤害=original_dmg/2。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 1,
        'abnormal_prob': 0.105
    }
)

run_test_case2(
    title="霸者1级-K连击(k=2)",
    description="霸者1级 + 连击(k=2)：每回合2次攻击，反弹可能被多次触发。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'overlord', 'emblem_level': 1,
        'abnormal_prob': 0.333
    }
)

run_test_case2(
    title="霸者1级-魔攻怪物(Magic)",
    description="霸者1级 vs 魔攻：魔攻无视反弹/霸体，反弹不触发。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 1,
        'abnormal_prob': 0.052
    }
)

# ====== 霸者之证 2级 测试 ======
run_test_case2(
    title="霸者2级-普通怪物",
    description="霸者2级：反弹概率11%，霸体概率11%。测试反弹与霸体组合。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 2,
        'abnormal_prob': 0.198
    }
)

run_test_case2(
    title="霸者2级-坚固怪物(Solid)",
    description="霸者2级 + 坚固：霸体加倍防御可能被触发，影响伤害计算。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 2,
        'abnormal_prob': 0.485
    }
)

run_test_case2(
    title="霸者2级-仿攻怪物(Mimic)",
    description="霸者2级 + 仿攻：反弹伤害=original_dmg（2级提升），可能瞬杀。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 2,
        'abnormal_prob': 0.277
    }
)

run_test_case2(
    title="霸者2级-K连击(k=3)",
    description="霸者2级 + 连击(k=3)：高频反弹/霸体触发，测试耐久性。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'overlord', 'emblem_level': 2,
        'abnormal_prob': 0.015
    }
)

run_test_case2(
    title="霸者2级-魔攻怪物(Magic)",
    description="霸者2级 vs 魔攻：魔攻无视反弹/霸体，只能靠输出速度。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 2,
        'abnormal_prob': 0.399
    }
)

# ====== 霸者之证 3级 测试 ======
run_test_case2(
    title="霸者3级-普通怪物",
    description="霸者3级：反弹16%，霸体16%，破防11%。最强综合实力。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob': 0.412
    }
)

run_test_case2(
    title="霸者3级-坚固怪物(Solid)",
    description="霸者3级 + 坚固：破防+11%可突破坚固防御，测试输出提升。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob': 0.155
    }
)

run_test_case2(
    title="霸者3级-仿攻怪物(Mimic)",
    description="霸者3级 + 仿攻：反弹伤害=m_atk/3，可能造成秒杀。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob': 0.088
    }
)

run_test_case2(
    title="霸者3级-K连击(k=4)",
    description="霸者3级 + 连击(k=4)：破防+高反弹+霸体，极致耐久与输出。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob': 0.290
    }
)

run_test_case2(
    title="霸者3级-魔攻怪物(Magic)",
    description="霸者3级 vs 魔攻：魔攻无视反弹/霸体，但破防11%仍有效。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob': 0.499
    }
)
# Out:
# ...
# 测试案例: 霸者1级-普通怪物
# 描述: 霸者1级：反弹概率6%，无霸体。测试基础反弹机制。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 1)
# 【异常状态概率】: 0.231
# ------------------------------------------------------------
# 【公式预期】: 0.4948
# 【模拟频率】: 0.4962
# 【误差分析】: 误差 0.0014
# ------------------------------
# 【蒙特卡洛模拟异常状态统计结果】
# 模拟次数     : 20000
# 异常状态次数 : 9924
# 异常状态频率 : 0.4962
# ------------------------------
# ...
# 测试案例: 霸者1级-坚固怪物(Solid)
# 描述: 霸者1级 + 坚固怪物：测试反弹与坚固属性交互。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 1)
# ...

# %% [markdown]
# ## 霸者之证含有秒杀的测试

# %%
# ====== 霸者之证 1级 测试 (怪物不能破防) ======
run_test_case2(
    title="霸者1级-零伤普通",
    description="霸者1级：勇士防御极高 ($H_{def}=500 > M_{atk}=30$)，怪物伤害恒为0。测试破防能否正确计算期望回合数。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.2, # H_def 确保 M_atk 无法破防
        'special_type': 'k_combo', 'k_value': 1,
        'emblem_type': 'overlord', 'emblem_level': 1,
        'abnormal_prob': 0.15 
    }
)

run_test_case2(
    title="霸者1级-零伤高防(Solid)",
    description="霸者1级 + 坚固：勇士 ($H_{atk}=50$) 攻击高防 ($M_{def}=100$) 怪物，怪物 ($M_{atk}=35$) 无法破勇士 ($H_{def}=500$) 防。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 150, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.15, # H_def 确保 M_atk 无法破防
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 1,
        'abnormal_prob': 0.22 
    }
)

run_test_case2(
    title="霸者1级-零伤连击(k=3)",
    description="霸者1级 + 连击(k=3)：怪物 ($M_{atk}=25$) 连击无法破勇士 ($H_{def}=500$) 防，测试零伤连击情况。",
    sim_params={
        'm_hp': 1500, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.18, # H_def 确保 M_atk 无法破防
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'overlord', 'emblem_level': 1,
        'abnormal_prob': 0.38
    }
)

# ====== 霸者之证 2级 测试 (怪物不能破防) ======
run_test_case2(
    title="霸者2级-零伤普通",
    description="霸者2级：16%霸体。由于 $H_{def}$ 极高，霸体效果不会改变零伤结果。测试 $E[Y|w=0]=0$。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.2, # H_def 确保 M_atk 无法破防
        'special_type': 'k_combo', 'k_value': 1,
        'emblem_type': 'overlord', 'emblem_level': 2,
        'abnormal_prob': 0.11 
    }
)

run_test_case2(
    title="霸者2级-零伤高攻(Mimic)",
    description="霸者2级 + 仿攻：高攻怪物 ($M_{atk}=50$) 仍无法破防 ($H_{def}=500$)。",
    sim_params={
        'm_hp': 800, 'm_atk': 50, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1, # H_def 确保 M_atk 无法破防
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 2,
        'abnormal_prob': 0.30 
    }
)

run_test_case2(
    title="霸者2级-零伤连击(k=4)",
    description="霸者2级 + 连击(k=4)：连击次数增加，但每次攻击伤害均为0。",
    sim_params={
        'm_hp': 2000, 'm_atk': 40, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.18, # H_def 确保 M_atk 无法破防
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'overlord', 'emblem_level': 2,
        'abnormal_prob': 0.40 
    }
)

# ====== 霸者之证 3级 测试 (怪物不能破防, DP 公式适用) ======
run_test_case2(
    title="霸者3级-零伤普通",
    description="霸者3级：反伤(1/3)。怪物 ($M_{atk}=30$) 无法破防 ($H_{def}=500$)，但反弹伤害 ($D_{base}/3$) 仍能对怪物造成伤害，测试反伤 DP 机制。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.2, # H_def 确保 M_atk 无法破防
        'special_type': 'k_combo', 'k_value': 1,
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob': 0.18 
    }
)

run_test_case2(
    title="霸者3级-零伤高防(Solid)",
    description="霸者3级 + 坚固：勇士 ($H_{atk}=50$) 攻击高防 ($M_{def}=100$) 怪物，怪物 ($M_{atk}=35$) 无法破勇士防，但反伤 ($35/3$) 造成伤害。",
    sim_params={
        'm_hp': 1200, 'm_atk': 35, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.15, # H_def 确保 M_atk 无法破防
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob': 0.25 
    }
)

run_test_case2(
    title="霸者3级-零伤高攻连击(k=2)",
    description="霸者3级 + K连击(k=2)：怪物 ($M_{atk}=120$) 无法破防 ($H_{def}=500$)，反伤 ($120/3=40$) 对怪物造成可观伤害。",
    sim_params={
        'm_hp': 1500, 'm_atk': 120, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.18, # H_def 确保 M_atk 无法破防
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob': 0.33 
    }
)
# Out:
# ...
# 测试案例: 霸者1级-零伤普通
# 描述: 霸者1级：勇士防御极高 ($H_{def}=500 > M_{atk}=30$)，怪物伤害恒为0。测试破防能否正确计算期望回合数。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 1
# 【徽章类型】: overlord (等级 1)
# 【异常状态概率】: 0.15
# ------------------------------------------------------------
# 【公式预期】: 0.2604
# 【模拟频率】: 0.2602
# 【误差分析】: 误差 0.0002
# ------------------------------
# 【蒙特卡洛模拟异常状态统计结果】
# 模拟次数     : 20000
# 异常状态次数 : 5204
# 异常状态频率 : 0.2602
# ------------------------------
# ...
# 测试案例: 霸者1级-零伤高防(Solid)
# 描述: 霸者1级 + 坚固：勇士 ($H_{atk}=50$) 攻击高防 ($M_{def}=100$) 怪物，怪物 ($M_{atk}=35$) 无法破勇士 ($H_{def}=500$) 防。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 150
# ...

# %% [markdown]
# # 勇者之证测试

# %%
# ====== 勇者之证 1级 测试 ======
run_test_case2(
    title="勇者1级-普通怪物",
    description="勇者1级：无特殊效果。测试基础数值。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 1,
        'abnormal_prob': 0.401
    }
)

run_test_case2(
    title="勇者1级-坚固怪物(Solid)",
    description="勇者1级 + 坚固：无攻击增益，防御压力大。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 1,
        'abnormal_prob': 0.075
    }
)

run_test_case2(
    title="勇者1级-仿攻怪物(Mimic)",
    description="勇者1级 + 仿攻：没有攻击加成，容易被反伤。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 1,
        'abnormal_prob': 0.355
    }
)

run_test_case2(
    title="勇者1级-K连击(k=2)",
    description="勇者1级 + 连击(k=2)：无加成，伤害压力大。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'hero', 'emblem_level': 1,
        'abnormal_prob': 0.111
    }
)

run_test_case2(
    title="勇者1级-魔攻怪物(Magic)",
    description="勇者1级 vs 魔攻：无特殊对抗能力。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 1,
        'abnormal_prob': 0.288
    }
)

# ====== 勇者之证 2级 测试 ======
run_test_case2(
    title="勇者2级-普通怪物",
    description="勇者2级：每回合2次攻击。伤害输出翻倍。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 2,
        'abnormal_prob': 0.470
    }
)

run_test_case2(
    title="勇者2级-坚固怪物(Solid)",
    description="勇者2级 + 坚固：2次攻击可能击穿或触发暴击。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 2,
        'abnormal_prob': 0.022
    }
)

run_test_case2(
    title="勇者2级-仿攻怪物(Mimic)",
    description="勇者2级 + 仿攻：2次高伤害输出对阵反伤。",
    sim_params={
        'm_hp': 8000, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 2,
        'abnormal_prob': 0.317
    }
)

run_test_case2(
    title="勇者2级-K连击(k=3)",
    description="勇者2级 + 连击(k=3)：2次vs 3次，频率竞争。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'hero', 'emblem_level': 2,
        'abnormal_prob': 0.170
    }
)

run_test_case2(
    title="勇者2级-魔攻怪物(Magic)",
    description="勇者2级 vs 魔攻：2次攻击应对魔攻伤害。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 2,
        'abnormal_prob': 0.435
    }
)

# ====== 勇者之证 3级 测试 ======
run_test_case2(
    title="勇者3级-普通怪物",
    description="勇者3级：每回合2次攻击+16%额外伤害。最强输出。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 3,
        'abnormal_prob': 0.099
    }
)

run_test_case2(
    title="勇者3级-坚固怪物(Solid)",
    description="勇者3级 + 坚固：额外伤害加成可能突破坚固防御。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 3,
        'abnormal_prob': 0.265
    }
)

run_test_case2(
    title="勇者3级-仿攻怪物(Mimic)",
    description="勇者3级 + 仿攻：2次高伤害+加成vs反伤，输出优势明显。",
    sim_params={
        'm_hp': 8000, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 3,
        'abnormal_prob': 0.491
    }
)

run_test_case2(
    title="勇者3级-K连击(k=4)",
    description="勇者3级 + 连击(k=4)：2次高伤害+加成vs 4次连击。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'hero', 'emblem_level': 3,
        'abnormal_prob': 0.140
    }
)

run_test_case2(
    title="勇者3级-魔攻怪物(Magic)",
    description="勇者3级 vs 魔攻：2次攻击+加成应对无视防御伤害。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 3,
        'abnormal_prob': 0.379
    }
)
# Out:
# ...
# 测试案例: 勇者1级-普通怪物
# 描述: 勇者1级：无特殊效果。测试基础数值。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 1)
# 【异常状态概率】: 0.401
# ------------------------------------------------------------
# 【公式预期】: 0.7227
# 【模拟频率】: 0.7197
# 【误差分析】: 误差 0.0030
# ------------------------------
# 【蒙特卡洛模拟异常状态统计结果】
# 模拟次数     : 20000
# 异常状态次数 : 14394
# 异常状态频率 : 0.7197
# ------------------------------
# ...
# 测试案例: 勇者1级-坚固怪物(Solid)
# 描述: 勇者1级 + 坚固：无攻击增益，防御压力大。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 1)
# 【异常状态概率】: 0.075
# ...

# %% [markdown]
# ## 勇者之证含有秒杀的测试

# %%
# ====== 勇者之证 1级 测试 ======
run_test_case2(
    title="勇者1级-零伤普通",
    description="勇者1级（+10% ATK）：勇士血量参数缺失。怪物攻击 30 无法破防 500。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.2,
        'special_type': 'k_combo', 'k_value': 1,
        'emblem_type': 'hero', 'emblem_level': 1,
        'abnormal_prob': 0.15 
    }
)

run_test_case2(
    title="勇者1级-高防怪物",
    description="勇者1级（+10% ATK）：勇士血量参数缺失。高防怪物 $M_{def}=100$。",
    sim_params={
        'm_hp': 90, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.2,
        'special_type': 'k_combo', 'k_value': 1,
        'emblem_type': 'hero', 'emblem_level': 1,
        'abnormal_prob': 0.22 
    }
)

# ====== 勇者之证 2级 测试 ======
run_test_case2(
    title="勇者2级-高防怪物",
    description="勇者2级（+15% ATK）：勇士血量参数缺失。高防怪物 $M_{def}=100$，零伤条件维持。",
    sim_params={
        'm_hp': 120, 'm_atk': 30, 'm_def': 30, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.15,
        'emblem_type': 'hero', 'emblem_level': 2,
        'abnormal_prob': 0.38 
    }
)

run_test_case2(
    title="勇者2级-连击怪物",
    description="勇者2级（+15% ATK）：勇士血量参数缺失。K 连击 ($k=3$) 怪物。",
    sim_params={
        'm_hp': 1500, 'm_atk': 30, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'hero', 'emblem_level': 2,
        'abnormal_prob': 0.11 
    }
)

# ====== 勇者之证 3级 测试 ======
run_test_case2(
    title="勇者3级-连击怪物",
    description="勇者3级（+20% ATK）：勇士血量参数缺失。连击 ($k=4$) 怪物。",
    sim_params={
        'm_hp': 2000, 'm_atk': 30, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'hero', 'emblem_level': 3,
        'abnormal_prob': 0.30 
    }
)

run_test_case2(
    title="勇者3级-仿攻怪物",
    description="勇者3级（+20% ATK）：勇士血量参数缺失。怪物为仿攻。",
    sim_params={
        'm_hp': 800, 'm_atk': 50, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 3,
        'abnormal_prob': 0.40 
    }
)
# Out:
# ...
# 测试案例: 勇者1级-零伤普通
# 描述: 勇者1级（+10% ATK）：勇士血量参数缺失。怪物攻击 30 无法破防 500。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 1
# 【徽章类型】: hero (等级 1)
# 【异常状态概率】: 0.15
# ------------------------------------------------------------
# 【公式预期】: 0.2553
# 【模拟频率】: 0.2590
# 【误差分析】: 误差 0.0037
# ------------------------------
# 【蒙特卡洛模拟异常状态统计结果】
# 模拟次数     : 20000
# 异常状态次数 : 5180
# 异常状态频率 : 0.2590
# ------------------------------
# ...
# 测试案例: 勇者1级-高防怪物
# 描述: 勇者1级（+10% ATK）：勇士血量参数缺失。高防怪物 $M_{def}=100$。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
# ...

# %% [markdown]
# # 随便测试

# %%
run_test_case2(
    title="随便测试",
    description="随便测试",
    sim_params={
        'm_hp': 1412, 'm_atk': 623, 'm_def': 224, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 424, 'h_def': 940, 'h_eva': 0.4, 'h_crit': 0,'h_atk_thresh': 5,'h_def_thresh':2,
        'emblem_type': 'overlord', 'emblem_level': 3,
        'abnormal_prob':0.2
    },
    n_trials=100000
)
# Out:
# ...
# 测试案例: 随便测试
# 描述: 随便测试
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1412
#   攻击力(ATK): 623
#   防御力(DEF): 224
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 424
#   防御力(DEF): 940
#   闪避率(EVA): 0.4
#   暴击率(CRIT): 0
# 【临界值】: 攻击 5, 防御 2
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 3)
# 【异常状态概率】: 0.2
# ------------------------------------------------------------
# 【公式预期】: 0.4087
# 【模拟频率】: 0.4090
# 【误差分析】: 误差 0.0003
# ------------------------------
# 【蒙特卡洛模拟异常状态统计结果】
# 模拟次数     : 100000
# 异常状态次数 : 40897
# 异常状态频率 : 0.4090
# ------------------------------
