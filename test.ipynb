# %%
from damage import run_test_case

# %% [markdown]
# # 无章测试

# %%
run_test_case(
    title="基础数学验证 (无概率)",
    description="验证基础伤害扣减和回合数计算是否准确 (预期伤害 40)。",
    sim_params={
        'm_hp': 100, 'm_atk': 20, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 30, 'h_def': 10, 'h_eva': 0, 'h_crit': 0
    }
)

run_test_case(
    title="临界值 1点伤害测试",
    description="勇士不破防，但达到攻击临界值，造成强制1点伤害。",
    sim_params={
        'm_hp': 5, 'm_atk': 100, 'm_def': 50, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 50, 'h_def': 0, 'h_eva': 0, 'h_crit': 0,
        'h_atk_thresh': 5
    }
)

run_test_case(
    title="坚固怪物 (Solid) + 50% 暴击",
    description="怪物防御自动调整为勇士攻击力，依赖临界值和暴击输出。",
    sim_params={
        'm_hp': 15, 'm_atk': 50, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 100, 'h_def': 40, 'h_eva': 0, 'h_crit': 0.5,
        'h_atk_thresh': 10, 'special_type': 'solid'
    },
    n_trials=50000 # 增加次数以稳定结果
)

run_test_case(
    title="魔攻怪物 (Magic) + 50% 闪避",
    description="勇士防御极高但被魔攻无视，依靠50%闪避减少伤害。",
    sim_params={
        'm_hp': 100, 'm_atk': 50, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 35, 'h_def': 1000, 'h_eva': 0.5, 'h_crit': 0,
        'special_type': 'magic'
    }
)

run_test_case(
    title="3连击怪物 (K-Combo)",
    description="怪物每回合攻击3次，测试高频攻击下的伤害累积。",
    sim_params={
        'm_hp': 200, 'm_atk': 20, 'm_def': 0, 'm_eva': 0.1, 'm_crit': 0.2,
        'h_atk': 30, 'h_def': 10, 'h_eva': 0.1, 'h_crit': 0.3,
        'special_type': 'k_combo', 'k_value': 3
    }
)

run_test_case(
    title="仿攻怪物 (Mimic)",
    description="怪物攻击力复制勇士攻击力，造成巨额伤害。",
    sim_params={
        'm_hp': 500, 'm_atk': 10, 'm_def': 100, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 200, 'h_def': 50, 'h_eva': 0, 'h_crit': 0,
        'special_type': 'mimic'
    }
)

run_test_case(
    title="无法击败测试 (NaN)",
    description="勇士攻击力不足且未达临界值，预期返回 NaN。",
    sim_params={
        'm_hp': 100, 'm_atk': 10, 'm_def': 100, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 10, 'h_def': 10, 'h_eva': 0, 'h_crit': 0,
        'h_atk_thresh': 0
    },
    n_trials=100
)
# Out:
# ============================================================
# 测试案例: 基础数学验证 (无概率)
# 描述: 验证基础伤害扣减和回合数计算是否准确 (预期伤害 40)。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 20
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 30
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 40.0000
# 【模拟均值】: 40.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# 【T检验 P值】: 1.000000 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 40.0000
# 中位数 (Median) : 40.0000
# 最大值 (Max)    : 40.0000
# 最小值 (Min)    : 40.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 临界值 1点伤害测试
# 描述: 勇士不破防，但达到攻击临界值，造成强制1点伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 5
#   攻击力(ATK): 100
#   防御力(DEF): 50
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 0
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 5, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 400.0000
# 【模拟均值】: 400.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# 【T检验 P值】: 1.000000 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 400.0000
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : 400.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 坚固怪物 (Solid) + 50% 暴击
# 描述: 怪物防御自动调整为勇士攻击力，依赖临界值和暴击输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 15
#   攻击力(ATK): 50
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 100
#   防御力(DEF): 40
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.5
# 【临界值】: 攻击 10, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 92.2223
# 【模拟均值】: 92.2470
# 【误差分析】: 绝对误差 0.0247 / 相对误差 0.03%
# 【T检验 P值】: 0.602879 (自由度 df=49999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 50000
# 平均值 (Mean)   : 92.2470
# 中位数 (Median) : 90.0000
# 最大值 (Max)    : 140.0000
# 最小值 (Min)    : 70.0000
# 标准差 (Std Dev): 10.6201
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 魔攻怪物 (Magic) + 50% 闪避
# 描述: 勇士防御极高但被魔攻无视，依靠50%闪避减少伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 50
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 35
#   防御力(DEF): 1000
#   闪避率(EVA): 0.5
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 75.0000
# 【模拟均值】: 75.1725
# 【误差分析】: 绝对误差 0.1725 / 相对误差 0.23%
# 【T检验 P值】: 0.573366 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 75.1725
# 中位数 (Median) : 100.0000
# 最大值 (Max)    : 150.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 43.3222
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 3连击怪物 (K-Combo)
# 描述: 怪物每回合攻击3次，测试高频攻击下的伤害累积。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 200
#   攻击力(ATK): 20
#   防御力(DEF): 0
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.2
# 【勇士属性】
#   攻击力(ATK): 30
#   防御力(DEF): 10
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.3
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 167.8381
# 【模拟均值】: 168.3055
# 【误差分析】: 绝对误差 0.4674 / 相对误差 0.28%
# 【T检验 P值】: 0.143584 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 168.3055
# 中位数 (Median) : 160.0000
# 最大值 (Max)    : 460.0000
# 最小值 (Min)    : 50.0000
# 标准差 (Std Dev): 45.1943
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 仿攻怪物 (Mimic)
# 描述: 怪物攻击力复制勇士攻击力，造成巨额伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 500
#   攻击力(ATK): 10
#   防御力(DEF): 100
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 200
#   防御力(DEF): 50
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 600.0000
# 【模拟均值】: 600.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# 【T检验 P值】: 1.000000 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 600.0000
# 中位数 (Median) : 600.0000
# 最大值 (Max)    : 600.0000
# 最小值 (Min)    : 600.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 无法击败测试 (NaN)
# 描述: 勇士攻击力不足且未达临界值，预期返回 NaN。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 10
#   防御力(DEF): 100
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 10
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: NaN (无法击败)
# 【模拟结果】: NaN (无法击败)
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 100
# 结果: 勇士无法击败怪物 (NaN)
# ------------------------------

# %% [markdown]
# # 霸者之证测试

# %%
# ====== 霸者之证 1级 测试 ======
run_test_case(
    title="霸者1级-普通怪物",
    description="霸者1级：反弹概率6%，无霸体。测试基础反弹机制。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-坚固怪物(Solid)",
    description="霸者1级 + 坚固怪物：测试反弹与坚固属性交互。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-仿攻怪物(Mimic)",
    description="霸者1级 + 仿攻：怪物攻击被复制，反弹伤害=original_dmg/2。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-K连击(k=2)",
    description="霸者1级 + 连击(k=2)：每回合2次攻击，反弹可能被多次触发。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-魔攻怪物(Magic)",
    description="霸者1级 vs 魔攻：魔攻无视反弹/霸体，反弹不触发。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

# ====== 霸者之证 2级 测试 ======
run_test_case(
    title="霸者2级-普通怪物",
    description="霸者2级：反弹概率11%，霸体概率11%。测试反弹与霸体组合。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-坚固怪物(Solid)",
    description="霸者2级 + 坚固：霸体加倍防御可能被触发，影响伤害计算。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-仿攻怪物(Mimic)",
    description="霸者2级 + 仿攻：反弹伤害=original_dmg（2级提升），可能瞬杀。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-K连击(k=3)",
    description="霸者2级 + 连击(k=3)：高频反弹/霸体触发，测试耐久性。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-魔攻怪物(Magic)",
    description="霸者2级 vs 魔攻：魔攻无视反弹/霸体，只能靠输出速度。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

# ====== 霸者之证 3级 测试 ======
run_test_case(
    title="霸者3级-普通怪物",
    description="霸者3级：反弹16%，霸体16%，破防11%。最强综合实力。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-坚固怪物(Solid)",
    description="霸者3级 + 坚固：破防+11%可突破坚固防御，测试输出提升。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-仿攻怪物(Mimic)",
    description="霸者3级 + 仿攻：反弹伤害=m_atk/3，可能造成秒杀。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-K连击(k=4)",
    description="霸者3级 + 连击(k=4)：破防+高反弹+霸体，极致耐久与输出。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-魔攻怪物(Magic)",
    description="霸者3级 vs 魔攻：魔攻无视反弹/霸体，但破防11%仍有效。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 霸者1级-普通怪物
# 描述: 霸者1级：反弹概率6%，无霸体。测试基础反弹机制。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 35.5237
# 【模拟均值】: 35.5308
# 【误差分析】: 绝对误差 0.0071 / 相对误差 0.02%
# 【T检验 P值】: 0.940749 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 35.5308
# 中位数 (Median) : 36.0000
# 最大值 (Max)    : 120.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 13.5814
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者1级-坚固怪物(Solid)
# 描述: 霸者1级 + 坚固怪物：测试反弹与坚固属性交互。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1259.2780
# 【模拟均值】: 1258.5038
# 【误差分析】: 绝对误差 0.7742 / 相对误差 0.06%
# 【T检验 P值】: 0.557460 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1258.5038
# 中位数 (Median) : 1260.0000
# 最大值 (Max)    : 1980.0000
# 最小值 (Min)    : 555.0000
# 标准差 (Std Dev): 186.6406
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者1级-仿攻怪物(Mimic)
# 描述: 霸者1级 + 仿攻：怪物攻击被复制，反弹伤害=original_dmg/2。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 49.0680
# 【模拟均值】: 49.0245
# 【误差分析】: 绝对误差 0.0435 / 相对误差 0.09%
# 【T检验 P值】: 0.769324 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 49.0245
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 20.9772
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者1级-K连击(k=2)
# 描述: 霸者1级 + 连击(k=2)：每回合2次攻击，反弹可能被多次触发。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 76.8717
# 【模拟均值】: 76.9535
# 【误差分析】: 绝对误差 0.0818 / 相对误差 0.11%
# 【T检验 P值】: 0.588711 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 76.9535
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 190.0000
# 最小值 (Min)    : 10.0000
# 标准差 (Std Dev): 21.4032
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者1级-魔攻怪物(Magic)
# 描述: 霸者1级 vs 魔攻：魔攻无视反弹/霸体，反弹不触发。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 124.9757
# 【模拟均值】: 124.9960
# 【误差分析】: 绝对误差 0.0203 / 相对误差 0.02%
# 【T检验 P值】: 0.943892 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 124.9960
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 40.8578
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者2级-普通怪物
# 描述: 霸者2级：反弹概率11%，霸体概率11%。测试反弹与霸体组合。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 27.7978
# 【模拟均值】: 27.8001
# 【误差分析】: 绝对误差 0.0023 / 相对误差 0.01%
# 【T检验 P值】: 0.981317 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 27.8001
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 102.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 14.1538
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者2级-坚固怪物(Solid)
# 描述: 霸者2级 + 坚固：霸体加倍防御可能被触发，影响伤害计算。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 637.9596
# 【模拟均值】: 636.9503
# 【误差分析】: 绝对误差 1.0093 / 相对误差 0.16%
# 【T检验 P值】: 0.433012 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 636.9503
# 中位数 (Median) : 617.0000
# 最大值 (Max)    : 1583.0000
# 最小值 (Min)    : 101.0000
# 标准差 (Std Dev): 182.0403
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者2级-仿攻怪物(Mimic)
# 描述: 霸者2级 + 仿攻：反弹伤害=original_dmg（2级提升），可能瞬杀。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 44.5196
# 【模拟均值】: 44.3346
# 【误差分析】: 绝对误差 0.1850 / 相对误差 0.42%
# 【T检验 P值】: 0.258611 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 44.3346
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 23.1564
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者2级-K连击(k=3)
# 描述: 霸者2级 + 连击(k=3)：高频反弹/霸体触发，测试耐久性。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 83.1301
# 【模拟均值】: 83.4972
# 【误差分析】: 绝对误差 0.3671 / 相对误差 0.44%
# 【T检验 P值】: 0.069009 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 83.4972
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 240.0000
# 最小值 (Min)    : 5.0000
# 标准差 (Std Dev): 28.5504
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者2级-魔攻怪物(Magic)
# 描述: 霸者2级 vs 魔攻：魔攻无视反弹/霸体，只能靠输出速度。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 124.9757
# 【模拟均值】: 125.0820
# 【误差分析】: 绝对误差 0.1063 / 相对误差 0.09%
# 【T检验 P值】: 0.715370 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 125.0820
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 41.2381
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者3级-普通怪物
# 描述: 霸者3级：反弹16%，霸体16%，破防11%。最强综合实力。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 22.6745
# 【模拟均值】: 22.9122
# 【误差分析】: 绝对误差 0.2377 / 相对误差 1.05%
# 【T检验 P值】: 0.013376 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 22.9122
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 96.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 13.5867
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者3级-坚固怪物(Solid)
# 描述: 霸者3级 + 坚固：破防+11%可突破坚固防御，测试输出提升。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 216.5228
# 【模拟均值】: 216.0108
# 【误差分析】: 绝对误差 0.5120 / 相对误差 0.24%
# 【T检验 P值】: 0.507372 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 216.0108
# 中位数 (Median) : 205.0000
# 最大值 (Max)    : 755.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 109.2275
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者3级-仿攻怪物(Mimic)
# 描述: 霸者3级 + 仿攻：反弹伤害=m_atk/3，可能造成秒杀。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 41.1869
# 【模拟均值】: 41.1118
# 【误差分析】: 绝对误差 0.0751 / 相对误差 0.18%
# 【T检验 P值】: 0.663465 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 41.1118
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 24.4011
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者3级-K连击(k=4)
# 描述: 霸者3级 + 连击(k=4)：破防+高反弹+霸体，极致耐久与输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 95.8761
# 【模拟均值】: 95.5874
# 【误差分析】: 绝对误差 0.2887 / 相对误差 0.30%
# 【T检验 P值】: 0.222200 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 95.5874
# 中位数 (Median) : 93.0000
# 最大值 (Max)    : 280.0000
# 最小值 (Min)    : 3.0000
# 标准差 (Std Dev): 33.4498
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 霸者3级-魔攻怪物(Magic)
# 描述: 霸者3级 vs 魔攻：魔攻无视反弹/霸体，但破防11%仍有效。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 113.7815
# 【模拟均值】: 113.5220
# 【误差分析】: 绝对误差 0.2595 / 相对误差 0.23%
# 【T检验 P值】: 0.384614 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 113.5220
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 360.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 42.2124
# ------------------------------
# ============================================================

# %% [markdown]
# # 贤者之证测试

# %%
# ====== 贤者之证 1级 测试 ======
run_test_case(
    title="贤者1级-普通怪物",
    description="贤者1级：闪避61%，集能减伤50点+随机回血。测试基础防御与集能机制。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-坚固怪物(Solid)",
    description="贤者1级 + 坚固：集能减伤50点对高防的影响有限，闪避更重要。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-仿攻怪物(Mimic)",
    description="贤者1级 + 仿攻：闪避对高伤害的减轻效果显著。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-K连击(k=2)",
    description="贤者1级 + 连击(k=2)：多次攻击中闪避可能多次触发，减伤累积。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-魔攻怪物(Magic)",
    description="贤者1级 vs 魔攻：魔攻无视闪避/集能，测试最坏情况。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

# ====== 贤者之证 2级 测试 ======
run_test_case(
    title="贤者2级-普通怪物",
    description="贤者2级：闪避81%，集能减伤100点+随机回血。防御力大幅提升。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-坚固怪物(Solid)",
    description="贤者2级 + 坚固：集能减伤100点对比1级翻倍，但坚固防御仍可能胜出。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-仿攻怪物(Mimic)",
    description="贤者2级 + 仿攻：高闪避(81%)对仿攻威胁大幅减弱。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-K连击(k=3)",
    description="贤者2级 + 连击(k=3)：高闪避+高集能减伤，连击伤害被极度削弱。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-魔攻怪物(Magic)",
    description="贤者2级 vs 魔攻：魔攻无视防御，但集能减伤100仍有基础保障。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

# ====== 贤者之证 3级 测试 ======
run_test_case(
    title="贤者3级-普通怪物",
    description="贤者3级：闪避100%（无法被击中），集能减伤100点+随机回血。终极防御。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-坚固怪物(Solid)",
    description="贤者3级 + 坚固：完全闪避(100%)使坚固防御失效，贤者绝对优势。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-仿攻怪物(Mimic)",
    description="贤者3级 + 仿攻：完全闪避使仿攻无威胁，集能减伤兜底。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-K连击(k=4)",
    description="贤者3级 + 连击(k=4)：完全闪避+集能减伤100，连击完全无效。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-魔攻怪物(Magic)",
    description="贤者3级 vs 魔攻：完全闪避对魔攻无效，但集能减伤100仍提供保护。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 贤者1级-普通怪物
# 描述: 贤者1级：闪避61%，集能减伤50点+随机回血。测试基础防御与集能机制。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 35.3136
# 【模拟均值】: 35.1285
# 【误差分析】: 绝对误差 0.1851 / 相对误差 0.52%
# 【T检验 P值】: 0.064615 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 35.1285
# 中位数 (Median) : 36.0000
# 最大值 (Max)    : 132.0000
# 最小值 (Min)    : -12.0000
# 标准差 (Std Dev): 14.1619
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者1级-坚固怪物(Solid)
# 描述: 贤者1级 + 坚固：集能减伤50点对高防的影响有限，闪避更重要。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1762.3062
# 【模拟均值】: 1761.9092
# 【误差分析】: 绝对误差 0.3970 / 相对误差 0.02%
# 【T检验 P值】: 0.569557 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1761.9092
# 中位数 (Median) : 1763.0000
# 最大值 (Max)    : 2251.0000
# 最小值 (Min)    : 1385.0000
# 标准差 (Std Dev): 98.7293
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者1级-仿攻怪物(Mimic)
# 描述: 贤者1级 + 仿攻：闪避对高伤害的减轻效果显著。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 52.2000
# 【模拟均值】: 52.0057
# 【误差分析】: 绝对误差 0.1943 / 相对误差 0.37%
# 【T检验 P值】: 0.119662 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 52.0057
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 17.6565
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者1级-K连击(k=2)
# 描述: 贤者1级 + 连击(k=2)：多次攻击中闪避可能多次触发，减伤累积。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 77.4846
# 【模拟均值】: 77.1890
# 【误差分析】: 绝对误差 0.2956 / 相对误差 0.38%
# 【T检验 P值】: 0.056012 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 77.1890
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 190.0000
# 最小值 (Min)    : 10.0000
# 标准差 (Std Dev): 21.8726
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者1级-魔攻怪物(Magic)
# 描述: 贤者1级 vs 魔攻：魔攻无视闪避/集能，测试最坏情况。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 124.2114
# 【模拟均值】: 124.1500
# 【误差分析】: 绝对误差 0.0614 / 相对误差 0.05%
# 【T检验 P值】: 0.833793 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 124.1500
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 360.0000
# 最小值 (Min)    : -16.0000
# 标准差 (Std Dev): 41.3830
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者2级-普通怪物
# 描述: 贤者2级：闪避81%，集能减伤100点+随机回血。防御力大幅提升。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 14.3868
# 【模拟均值】: 14.2197
# 【误差分析】: 绝对误差 0.1670 / 相对误差 1.16%
# 【T检验 P值】: 0.531233 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 14.2197
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 120.0000
# 最小值 (Min)    : -216.0000
# 标准差 (Std Dev): 37.7233
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者2级-坚固怪物(Solid)
# 描述: 贤者2级 + 坚固：集能减伤100点对比1级翻倍，但坚固防御仍可能胜出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 934.8700
# 【模拟均值】: 933.3327
# 【误差分析】: 绝对误差 1.5373 / 相对误差 0.16%
# 【T检验 P值】: 0.373841 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 933.3327
# 中位数 (Median) : 943.0000
# 最大值 (Max)    : 1735.0000
# 最小值 (Min)    : -144.0000
# 标准差 (Std Dev): 244.4649
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者2级-仿攻怪物(Mimic)
# 描述: 贤者2级 + 仿攻：高闪避(81%)对仿攻威胁大幅减弱。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 45.8145
# 【模拟均值】: 45.4473
# 【误差分析】: 绝对误差 0.3672 / 相对误差 0.80%
# 【T检验 P值】: 0.037337 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 45.4473
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : -21.0000
# 标准差 (Std Dev): 24.9400
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者2级-K连击(k=3)
# 描述: 贤者2级 + 连击(k=3)：高闪避+高集能减伤，连击伤害被极度削弱。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 34.5093
# 【模拟均值】: 34.5746
# 【误差分析】: 绝对误差 0.0652 / 相对误差 0.19%
# 【T检验 P值】: 0.903053 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 34.5746
# 中位数 (Median) : 44.0000
# 最大值 (Max)    : 230.0000
# 最小值 (Min)    : -409.0000
# 标准差 (Std Dev): 75.7403
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者2级-魔攻怪物(Magic)
# 描述: 贤者2级 vs 魔攻：魔攻无视防御，但集能减伤100仍有基础保障。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 123.9608
# 【模拟均值】: 123.7148
# 【误差分析】: 绝对误差 0.2460 / 相对误差 0.20%
# 【T检验 P值】: 0.404128 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 123.7148
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : -24.0000
# 标准差 (Std Dev): 41.7042
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者3级-普通怪物
# 描述: 贤者3级：闪避100%（无法被击中），集能减伤100点+随机回血。终极防御。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -23.5131
# 【模拟均值】: -23.8203
# 【误差分析】: 绝对误差 0.3072 / 相对误差 1.31%
# 【T检验 P值】: 0.431361 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -23.8203
# 中位数 (Median) : -24.0000
# 最大值 (Max)    : 108.0000
# 最小值 (Min)    : -360.0000
# 标准差 (Std Dev): 55.2147
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者3级-坚固怪物(Solid)
# 描述: 贤者3级 + 坚固：完全闪避(100%)使坚固防御失效，贤者绝对优势。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -562.9377
# 【模拟均值】: -562.4804
# 【误差分析】: 绝对误差 0.4574 / 相对误差 0.08%
# 【T检验 P值】: 0.854411 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -562.4804
# 中位数 (Median) : -555.0000
# 最大值 (Max)    : 745.0000
# 最小值 (Min)    : -1961.0000
# 标准差 (Std Dev): 352.5196
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者3级-仿攻怪物(Mimic)
# 描述: 贤者3级 + 仿攻：完全闪避使仿攻无威胁，集能减伤兜底。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 34.2045
# 【模拟均值】: 34.0829
# 【误差分析】: 绝对误差 0.1217 / 相对误差 0.36%
# 【T检验 P值】: 0.578022 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 34.0829
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : -21.0000
# 标准差 (Std Dev): 30.9264
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者3级-K连击(k=4)
# 描述: 贤者3级 + 连击(k=4)：完全闪避+集能减伤100，连击完全无效。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -151.4662
# 【模拟均值】: -152.3382
# 【误差分析】: 绝对误差 0.8719 / 相对误差 0.58%
# 【T检验 P值】: 0.356699 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -152.3382
# 中位数 (Median) : -142.0000
# 最大值 (Max)    : 220.0000
# 最小值 (Min)    : -770.0000
# 标准差 (Std Dev): 133.7831
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者3级-魔攻怪物(Magic)
# 描述: 贤者3级 vs 魔攻：完全闪避对魔攻无效，但集能减伤100仍提供保护。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 27.1791
# 【模拟均值】: 27.2274
# 【误差分析】: 绝对误差 0.0483 / 相对误差 0.18%
# 【T检验 P值】: 0.950463 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 27.2274
# 中位数 (Median) : 53.0000
# 最大值 (Max)    : 360.0000
# 最小值 (Min)    : -498.0000
# 标准差 (Std Dev): 110.0045
# ------------------------------
# ============================================================

# %% [markdown]
# ## 贤者之证含有秒杀的测试

# %%
# ====== 贤者之证 1级 补充测试 ======
run_test_case(
    title="贤者1级-补充-零伤固防",
    description="贤者1级 + 坚固：勇士防御极高，结合集能减伤50点，使怪物伤害为0。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.2, # 极高防御
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-补充-零伤多击",
    description="贤者1级 + K连击(k=2)：勇士防御极高，保证怪物每次连击伤害均为0。",
    sim_params={
        'm_hp': 1500, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.18, # 极高防御
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

# ====== 贤者之证 2级 补充测试 ======
run_test_case(
    title="贤者2级-补充-零伤仿攻",
    description="贤者2级 + 仿攻：勇士高防 + 集能减伤100点，应对仿攻的低基攻。",
    sim_params={
        'm_hp': 8000, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.1, # 极高防御
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-补充-零伤高攻",
    description="贤者2级：集能减伤100点，配合闪避和防御，抵消较高攻击力的怪物。",
    sim_params={
        'm_hp': 1200, 'm_atk': 120, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 250, 'h_eva': 0.3, 'h_crit': 0.15,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

# ====== 贤者之证 3级 补充测试 ======
run_test_case(
    title="贤者3级-补充-零伤连击",
    description="贤者3级 + K连击(k=4)：100%闪避确保怪物无法命中，集能减伤100为理论零伤提供支持。",
    sim_params={
        'm_hp': 1500, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 150, 'h_eva': 0.35, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-补充-零伤极限高攻",
    description="贤者3级：100%闪避直接判定为零伤害，但仍验证集能减伤100对高攻的保障。",
    sim_params={
        'm_hp': 2000, 'm_atk': 500, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 550, 'h_def': 2500, 'h_eva': 0.45, 'h_crit': 0.15,
        # 勇士攻击远大于怪物防御，战斗结束；怪物攻击极高，但会被100%闪避完全抵消
        'emblem_type': 'sage', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 贤者1级-补充-零伤固防
# 描述: 贤者1级 + 坚固：勇士防御极高，结合集能减伤50点，使怪物伤害为0。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: -100.7381
# 【模拟均值】: -100.6926
# 【误差分析】: 绝对误差 0.0455 / 相对误差 0.05%
# 【T检验 P值】: 0.776213 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -100.6926
# 中位数 (Median) : -102.0000
# 最大值 (Max)    : -18.0000
# 最小值 (Min)    : -198.0000
# 标准差 (Std Dev): 22.6420
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者1级-补充-零伤多击
# 描述: 贤者1级 + K连击(k=2)：勇士防御极高，保证怪物每次连击伤害均为0。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: -8.1683
# 【模拟均值】: -8.1085
# 【误差分析】: 绝对误差 0.0598 / 相对误差 0.73%
# 【T检验 P值】: 0.407156 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -8.1085
# 中位数 (Median) : -5.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -90.0000
# 标准差 (Std Dev): 10.2072
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者2级-补充-零伤仿攻
# 描述: 贤者2级 + 仿攻：勇士高防 + 集能减伤100点，应对仿攻的低基攻。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 8000
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 500
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: -34.7143
# 【模拟均值】: -34.9832
# 【误差分析】: 绝对误差 0.2689 / 相对误差 0.77%
# 【T检验 P值】: 0.366602 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -34.9832
# 中位数 (Median) : -16.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -368.0000
# 标准差 (Std Dev): 42.1245
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者2级-补充-零伤高攻
# 描述: 贤者2级：集能减伤100点，配合闪避和防御，抵消较高攻击力的怪物。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 120
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 250
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: -52.0662
# 【模拟均值】: -52.1148
# 【误差分析】: 绝对误差 0.0486 / 相对误差 0.09%
# 【T检验 P值】: 0.912351 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -52.1148
# 中位数 (Median) : -24.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -504.0000
# 标准差 (Std Dev): 62.3930
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者3级-补充-零伤连击
# 描述: 贤者3级 + K连击(k=4)：100%闪避确保怪物无法命中，集能减伤100为理论零伤提供支持。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 150
#   闪避率(EVA): 0.35
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -16.8269
# 【模拟均值】: -16.9443
# 【误差分析】: 绝对误差 0.1173 / 相对误差 0.70%
# 【T检验 P值】: 0.386024 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -16.9443
# 中位数 (Median) : -10.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -280.0000
# 标准差 (Std Dev): 19.1411
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 贤者3级-补充-零伤极限高攻
# 描述: 贤者3级：100%闪避直接判定为零伤害，但仍验证集能减伤100对高攻的保障。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 2000
#   攻击力(ATK): 500
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 550
#   防御力(DEF): 2500
#   闪避率(EVA): 0.45
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -114.6892
# 【模拟均值】: -115.2250
# 【误差分析】: 绝对误差 0.5358 / 相对误差 0.47%
# 【T检验 P值】: 0.412162 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -115.2250
# 中位数 (Median) : -100.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -500.0000
# 标准差 (Std Dev): 92.3857
# ------------------------------
# ============================================================

# %% [markdown]
# # 勇者之证测试

# %%
# ====== 勇者之证 1级 测试 ======
run_test_case(
    title="勇者1级-普通怪物",
    description="勇者1级：无特殊效果。测试基础数值。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-坚固怪物(Solid)",
    description="勇者1级 + 坚固：无攻击增益，防御压力大。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-仿攻怪物(Mimic)",
    description="勇者1级 + 仿攻：没有攻击加成，容易被反伤。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-K连击(k=2)",
    description="勇者1级 + 连击(k=2)：无加成，伤害压力大。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-魔攻怪物(Magic)",
    description="勇者1级 vs 魔攻：无特殊对抗能力。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

# ====== 勇者之证 2级 测试 ======
run_test_case(
    title="勇者2级-普通怪物",
    description="勇者2级：每回合2次攻击。伤害输出翻倍。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-坚固怪物(Solid)",
    description="勇者2级 + 坚固：2次攻击可能击穿或触发暴击。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-仿攻怪物(Mimic)",
    description="勇者2级 + 仿攻：2次高伤害输出对阵反伤。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-K连击(k=3)",
    description="勇者2级 + 连击(k=3)：2次vs 3次，频率竞争。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-魔攻怪物(Magic)",
    description="勇者2级 vs 魔攻：2次攻击应对魔攻伤害。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

# ====== 勇者之证 3级 测试 ======
run_test_case(
    title="勇者3级-普通怪物",
    description="勇者3级：每回合2次攻击+16%额外伤害。最强输出。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-坚固怪物(Solid)",
    description="勇者3级 + 坚固：额外伤害加成可能突破坚固防御。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-仿攻怪物(Mimic)",
    description="勇者3级 + 仿攻：2次高伤害+加成vs反伤，输出优势明显。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-K连击(k=4)",
    description="勇者3级 + 连击(k=4)：2次高伤害+加成vs 4次连击。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-魔攻怪物(Magic)",
    description="勇者3级 vs 魔攻：2次攻击+加成应对无视防御伤害。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 勇者1级-普通怪物
# 描述: 勇者1级：无特殊效果。测试基础数值。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 358.3653
# 【模拟均值】: 357.4200
# 【误差分析】: 绝对误差 0.9453 / 相对误差 0.26%
# 【T检验 P值】: 0.332471 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 357.4200
# 中位数 (Median) : 360.0000
# 最大值 (Max)    : 1320.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 137.9428
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者1级-坚固怪物(Solid)
# 描述: 勇者1级 + 坚固：无攻击增益，防御压力大。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 179855.6902
# 【模拟均值】: 179877.4200
# 【误差分析】: 绝对误差 21.7298 / 相对误差 0.01%
# 【T检验 P值】: 0.305207 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 179877.4200
# 中位数 (Median) : 179850.0000
# 最大值 (Max)    : 191400.0000
# 最小值 (Min)    : 168450.0000
# 标准差 (Std Dev): 2997.0576
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者1级-仿攻怪物(Mimic)
# 描述: 勇者1级 + 仿攻：没有攻击加成，容易被反伤。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 522.0000
# 【模拟均值】: 522.8120
# 【误差分析】: 绝对误差 0.8120 / 相对误差 0.16%
# 【T检验 P值】: 0.506633 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 522.8120
# 中位数 (Median) : 580.0000
# 最大值 (Max)    : 580.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 172.9164
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者1级-K连击(k=2)
# 描述: 勇者1级 + 连击(k=2)：无加成，伤害压力大。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 785.8147
# 【模拟均值】: 786.1700
# 【误差分析】: 绝对误差 0.3553 / 相对误差 0.05%
# 【T检验 P值】: 0.816017 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 786.1700
# 中位数 (Median) : 800.0000
# 最大值 (Max)    : 1900.0000
# 最小值 (Min)    : 100.0000
# 标准差 (Std Dev): 215.9400
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者1级-魔攻怪物(Magic)
# 描述: 勇者1级 vs 魔攻：无特殊对抗能力。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1249.7567
# 【模拟均值】: 1250.5800
# 【误差分析】: 绝对误差 0.8233 / 相对误差 0.07%
# 【T检验 P值】: 0.775783 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1250.5800
# 中位数 (Median) : 1200.0000
# 最大值 (Max)    : 3600.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 408.8056
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者2级-普通怪物
# 描述: 勇者2级：每回合2次攻击。伤害输出翻倍。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 147.4927
# 【模拟均值】: 147.0300
# 【误差分析】: 绝对误差 0.4627 / 相对误差 0.31%
# 【T检验 P值】: 0.401688 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 147.0300
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 600.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 78.0308
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者2级-坚固怪物(Solid)
# 描述: 勇者2级 + 坚固：2次攻击可能击穿或触发暴击。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 89886.8764
# 【模拟均值】: 89866.6500
# 【误差分析】: 绝对误差 20.2264 / 相对误差 0.02%
# 【T检验 P值】: 0.118443 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 89866.6500
# 中位数 (Median) : 89850.0000
# 最大值 (Max)    : 97200.0000
# 最小值 (Min)    : 82650.0000
# 标准差 (Std Dev): 1831.9590
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者2级-仿攻怪物(Mimic)
# 描述: 勇者2级 + 仿攻：2次高伤害输出对阵反伤。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 0.0000
# 【模拟均值】: 0.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 nan%
# 【T检验 P值】: 1.000000 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 0.0000
# 中位数 (Median) : 0.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者2级-K连击(k=3)
# 描述: 勇者2级 + 连击(k=3)：2次vs 3次，频率竞争。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 509.6890
# 【模拟均值】: 510.8950
# 【误差分析】: 绝对误差 1.2060 / 相对误差 0.24%
# 【T检验 P值】: 0.383508 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 510.8950
# 中位数 (Median) : 500.0000
# 最大值 (Max)    : 1400.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 195.7133
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者2级-魔攻怪物(Magic)
# 描述: 勇者2级 vs 魔攻：2次攻击应对魔攻伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 506.1334
# 【模拟均值】: 504.4800
# 【误差分析】: 绝对误差 1.6534 / 相对误差 0.33%
# 【T检验 P值】: 0.323461 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 504.4800
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 2000.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 236.8095
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者3级-普通怪物
# 描述: 勇者3级：每回合2次攻击+16%额外伤害。最强输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 146.5288
# 【模拟均值】: 146.2680
# 【误差分析】: 绝对误差 0.2608 / 相对误差 0.18%
# 【T检验 P值】: 0.638342 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 146.2680
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 600.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 78.4697
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者3级-坚固怪物(Solid)
# 描述: 勇者3级 + 坚固：额外伤害加成可能突破坚固防御。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 89886.8764
# 【模拟均值】: 89887.6425
# 【误差分析】: 绝对误差 0.7661 / 相对误差 0.00%
# 【T检验 P值】: 0.952819 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 89887.6425
# 中位数 (Median) : 89850.0000
# 最大值 (Max)    : 96750.0000
# 最小值 (Min)    : 83100.0000
# 标准差 (Std Dev): 1831.1955
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者3级-仿攻怪物(Mimic)
# 描述: 勇者3级 + 仿攻：2次高伤害+加成vs反伤，输出优势明显。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 0.0000
# 【模拟均值】: 0.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 nan%
# 【T检验 P值】: 1.000000 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 0.0000
# 中位数 (Median) : 0.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者3级-K连击(k=4)
# 描述: 勇者3级 + 连击(k=4)：2次高伤害+加成vs 4次连击。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 675.5472
# 【模拟均值】: 677.8900
# 【误差分析】: 绝对误差 2.3428 / 相对误差 0.35%
# 【T检验 P值】: 0.193900 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 677.8900
# 中位数 (Median) : 700.0000
# 最大值 (Max)    : 2000.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 255.0263
# ------------------------------
# ============================================================
# ============================================================
# 测试案例: 勇者3级-魔攻怪物(Magic)
# 描述: 勇者3级 vs 魔攻：2次攻击+加成应对无视防御伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 506.1334
# 【模拟均值】: 506.9600
# 【误差分析】: 绝对误差 0.8266 / 相对误差 0.16%
# 【T检验 P值】: 0.623888 (自由度 df=19999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 506.9600
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 2000.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 238.3997
# ------------------------------
# ============================================================

# %% [markdown]
# # 随便测试

# %%
run_test_case(
    title="随便测试",
    description="随便测试",
    sim_params={
        'm_hp': 1412, 'm_atk': 623, 'm_def': 224, 'm_eva': 0.14, 'm_crit': 0.15,
        'h_atk': 424, 'h_def': 240, 'h_eva': 0.23, 'h_crit': 0.16,'h_atk_thresh': 5,'h_def_thresh':2,
        'emblem_type': None, 'emblem_level': 3,
        'abnormal_prob':0.2
    },
    n_trials=100000
)
# Out:
# ============================================================
# 测试案例: 随便测试
# 描述: 随便测试
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1412
#   攻击力(ATK): 623
#   防御力(DEF): 224
#   闪避率(EVA): 0.14
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 424
#   防御力(DEF): 240
#   闪避率(EVA): 0.23
#   暴击率(CRIT): 0.16
# 【临界值】: 攻击 5, 防御 2
# 【特殊能力】: None
# 【徽章类型】: None (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 2427.4441
# 【模拟均值】: 2426.5271
# 【误差分析】: 绝对误差 0.9170 / 相对误差 0.04%
# 【T检验 P值】: 0.709391 (自由度 df=99999, 显著性水平=0.001)
# 假设检验通过: 解析解与模拟均值无显著差异。
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 100000
# 平均值 (Mean)   : 2426.5271
# 中位数 (Median) : 2298.0000
# 最大值 (Max)    : 7277.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 778.0942
# ------------------------------
# ============================================================
