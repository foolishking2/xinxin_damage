# %%
from damage import run_test_case

# %% [markdown]
# # 无章测试

# %%
run_test_case(
    title="基础数学验证 (无概率)",
    description="验证基础伤害扣减和回合数计算是否准确 (预期伤害 40)。",
    sim_params={
        'm_hp': 100, 'm_atk': 20, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 30, 'h_def': 10, 'h_eva': 0, 'h_crit': 0
    }
)

run_test_case(
    title="临界值 1点伤害测试",
    description="勇士不破防，但达到攻击临界值，造成强制1点伤害。",
    sim_params={
        'm_hp': 5, 'm_atk': 100, 'm_def': 50, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 50, 'h_def': 0, 'h_eva': 0, 'h_crit': 0,
        'h_atk_thresh': 5
    }
)

run_test_case(
    title="坚固怪物 (Solid) + 50% 暴击",
    description="怪物防御自动调整为勇士攻击力，依赖临界值和暴击输出。",
    sim_params={
        'm_hp': 15, 'm_atk': 50, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 100, 'h_def': 40, 'h_eva': 0, 'h_crit': 0.5,
        'h_atk_thresh': 10, 'special_type': 'solid'
    },
    n_trials=50000 # 增加次数以稳定结果
)

run_test_case(
    title="魔攻怪物 (Magic) + 50% 闪避",
    description="勇士防御极高但被魔攻无视，依靠50%闪避减少伤害。",
    sim_params={
        'm_hp': 100, 'm_atk': 50, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 35, 'h_def': 1000, 'h_eva': 0.5, 'h_crit': 0,
        'special_type': 'magic'
    }
)

run_test_case(
    title="3连击怪物 (K-Combo)",
    description="怪物每回合攻击3次，测试高频攻击下的伤害累积。",
    sim_params={
        'm_hp': 200, 'm_atk': 20, 'm_def': 0, 'm_eva': 0.1, 'm_crit': 0.2,
        'h_atk': 30, 'h_def': 10, 'h_eva': 0.1, 'h_crit': 0.3,
        'special_type': 'k_combo', 'k_value': 3
    }
)

run_test_case(
    title="仿攻怪物 (Mimic)",
    description="怪物攻击力复制勇士攻击力，造成巨额伤害。",
    sim_params={
        'm_hp': 500, 'm_atk': 10, 'm_def': 100, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 200, 'h_def': 50, 'h_eva': 0, 'h_crit': 0,
        'special_type': 'mimic'
    }
)

run_test_case(
    title="无法击败测试 (NaN)",
    description="勇士攻击力不足且未达临界值，预期返回 NaN。",
    sim_params={
        'm_hp': 100, 'm_atk': 10, 'm_def': 100, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 10, 'h_def': 10, 'h_eva': 0, 'h_crit': 0,
        'h_atk_thresh': 0
    },
    n_trials=100
)
# Out:
# ============================================================
# 测试案例: 基础数学验证 (无概率)
# 描述: 验证基础伤害扣减和回合数计算是否准确 (预期伤害 40)。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 20
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 30
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 40.0000
# 【模拟均值】: 40.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 40.0000
# 中位数 (Median) : 40.0000
# 最大值 (Max)    : 40.0000
# 最小值 (Min)    : 40.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 临界值 1点伤害测试
# 描述: 勇士不破防，但达到攻击临界值，造成强制1点伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 5
#   攻击力(ATK): 100
#   防御力(DEF): 50
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 0
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 5, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 400.0000
# 【模拟均值】: 400.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 400.0000
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : 400.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 坚固怪物 (Solid) + 50% 暴击
# 描述: 怪物防御自动调整为勇士攻击力，依赖临界值和暴击输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 15
#   攻击力(ATK): 50
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 100
#   防御力(DEF): 40
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.5
# 【临界值】: 攻击 10, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 92.2223
# 【模拟均值】: 92.1864
# 【误差分析】: 绝对误差 0.0359 / 相对误差 0.04%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 50000
# 平均值 (Mean)   : 92.1864
# 中位数 (Median) : 90.0000
# 最大值 (Max)    : 140.0000
# 最小值 (Min)    : 70.0000
# 标准差 (Std Dev): 10.6812
# ------------------------------
# ============================================================
# 测试案例: 魔攻怪物 (Magic) + 50% 闪避
# 描述: 勇士防御极高但被魔攻无视，依靠50%闪避减少伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 50
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 35
#   防御力(DEF): 1000
#   闪避率(EVA): 0.5
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 75.0000
# 【模拟均值】: 74.7100
# 【误差分析】: 绝对误差 0.2900 / 相对误差 0.39%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 74.7100
# 中位数 (Median) : 50.0000
# 最大值 (Max)    : 150.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 43.1412
# ------------------------------
# ============================================================
# 测试案例: 3连击怪物 (K-Combo)
# 描述: 怪物每回合攻击3次，测试高频攻击下的伤害累积。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 200
#   攻击力(ATK): 20
#   防御力(DEF): 0
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.2
# 【勇士属性】
#   攻击力(ATK): 30
#   防御力(DEF): 10
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.3
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 167.8381
# 【模拟均值】: 167.9440
# 【误差分析】: 绝对误差 0.1059 / 相对误差 0.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 167.9440
# 中位数 (Median) : 160.0000
# 最大值 (Max)    : 420.0000
# 最小值 (Min)    : 40.0000
# 标准差 (Std Dev): 44.3255
# ------------------------------
# ============================================================
# 测试案例: 仿攻怪物 (Mimic)
# 描述: 怪物攻击力复制勇士攻击力，造成巨额伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 500
#   攻击力(ATK): 10
#   防御力(DEF): 100
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 200
#   防御力(DEF): 50
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 600.0000
# 【模拟均值】: 600.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 600.0000
# 中位数 (Median) : 600.0000
# 最大值 (Max)    : 600.0000
# 最小值 (Min)    : 600.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 无法击败测试 (NaN)
# 描述: 勇士攻击力不足且未达临界值，预期返回 NaN。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 10
#   防御力(DEF): 100
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 10
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: NaN (无法击败)
# 【模拟结果】: NaN (无法击败)

# %% [markdown]
# # 霸者之证测试

# %%
# ====== 霸者之证 1级 测试 ======
run_test_case(
    title="霸者1级-普通怪物",
    description="霸者1级：反弹概率6%，无霸体。测试基础反弹机制。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-坚固怪物(Solid)",
    description="霸者1级 + 坚固怪物：测试反弹与坚固属性交互。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-仿攻怪物(Mimic)",
    description="霸者1级 + 仿攻：怪物攻击被复制，反弹伤害=original_dmg/2。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-K连击(k=2)",
    description="霸者1级 + 连击(k=2)：每回合2次攻击，反弹可能被多次触发。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-魔攻怪物(Magic)",
    description="霸者1级 vs 魔攻：魔攻无视反弹/霸体，反弹不触发。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

# ====== 霸者之证 2级 测试 ======
run_test_case(
    title="霸者2级-普通怪物",
    description="霸者2级：反弹概率11%，霸体概率11%。测试反弹与霸体组合。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-坚固怪物(Solid)",
    description="霸者2级 + 坚固：霸体加倍防御可能被触发，影响伤害计算。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-仿攻怪物(Mimic)",
    description="霸者2级 + 仿攻：反弹伤害=original_dmg（2级提升），可能瞬杀。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-K连击(k=3)",
    description="霸者2级 + 连击(k=3)：高频反弹/霸体触发，测试耐久性。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-魔攻怪物(Magic)",
    description="霸者2级 vs 魔攻：魔攻无视反弹/霸体，只能靠输出速度。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

# ====== 霸者之证 3级 测试 ======
run_test_case(
    title="霸者3级-普通怪物",
    description="霸者3级：反弹16%，霸体16%，破防11%。最强综合实力。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-坚固怪物(Solid)",
    description="霸者3级 + 坚固：破防+11%可突破坚固防御，测试输出提升。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-仿攻怪物(Mimic)",
    description="霸者3级 + 仿攻：反弹伤害=m_atk/3，可能造成秒杀。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-K连击(k=4)",
    description="霸者3级 + 连击(k=4)：破防+高反弹+霸体，极致耐久与输出。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-魔攻怪物(Magic)",
    description="霸者3级 vs 魔攻：魔攻无视反弹/霸体，但破防11%仍有效。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 霸者1级-普通怪物
# 描述: 霸者1级：反弹概率6%，无霸体。测试基础反弹机制。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 35.5237
# 【模拟均值】: 35.4720
# 【误差分析】: 绝对误差 0.0517 / 相对误差 0.15%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 35.4720
# 中位数 (Median) : 36.0000
# 最大值 (Max)    : 120.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 13.5747
# ------------------------------
# ============================================================
# 测试案例: 霸者1级-坚固怪物(Solid)
# 描述: 霸者1级 + 坚固怪物：测试反弹与坚固属性交互。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1259.2780
# 【模拟均值】: 1260.0218
# 【误差分析】: 绝对误差 0.7438 / 相对误差 0.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1260.0218
# 中位数 (Median) : 1260.0000
# 最大值 (Max)    : 1980.0000
# 最小值 (Min)    : 570.0000
# 标准差 (Std Dev): 185.2174
# ------------------------------
# ============================================================
# 测试案例: 霸者1级-仿攻怪物(Mimic)
# 描述: 霸者1级 + 仿攻：怪物攻击被复制，反弹伤害=original_dmg/2。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 49.0680
# 【模拟均值】: 49.2130
# 【误差分析】: 绝对误差 0.1450 / 相对误差 0.30%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 49.2130
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 20.7951
# ------------------------------
# ============================================================
# 测试案例: 霸者1级-K连击(k=2)
# 描述: 霸者1级 + 连击(k=2)：每回合2次攻击，反弹可能被多次触发。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 76.8717
# 【模拟均值】: 76.8360
# 【误差分析】: 绝对误差 0.0357 / 相对误差 0.05%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 76.8360
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 190.0000
# 最小值 (Min)    : 10.0000
# 标准差 (Std Dev): 21.2523
# ------------------------------
# ============================================================
# 测试案例: 霸者1级-魔攻怪物(Magic)
# 描述: 霸者1级 vs 魔攻：魔攻无视反弹/霸体，反弹不触发。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 124.9757
# 【模拟均值】: 124.9980
# 【误差分析】: 绝对误差 0.0223 / 相对误差 0.02%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 124.9980
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 40.5075
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-普通怪物
# 描述: 霸者2级：反弹概率11%，霸体概率11%。测试反弹与霸体组合。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 27.7978
# 【模拟均值】: 27.8943
# 【误差分析】: 绝对误差 0.0965 / 相对误差 0.35%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 27.8943
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 108.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 14.0424
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-坚固怪物(Solid)
# 描述: 霸者2级 + 坚固：霸体加倍防御可能被触发，影响伤害计算。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 637.9596
# 【模拟均值】: 637.2726
# 【误差分析】: 绝对误差 0.6871 / 相对误差 0.11%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 637.2726
# 中位数 (Median) : 625.0000
# 最大值 (Max)    : 1538.0000
# 最小值 (Min)    : 123.0000
# 标准差 (Std Dev): 180.7894
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-仿攻怪物(Mimic)
# 描述: 霸者2级 + 仿攻：反弹伤害=original_dmg（2级提升），可能瞬杀。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 44.5196
# 【模拟均值】: 44.7573
# 【误差分析】: 绝对误差 0.2377 / 相对误差 0.53%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 44.7573
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 22.8971
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-K连击(k=3)
# 描述: 霸者2级 + 连击(k=3)：高频反弹/霸体触发，测试耐久性。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 83.1301
# 【模拟均值】: 83.1658
# 【误差分析】: 绝对误差 0.0356 / 相对误差 0.04%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 83.1658
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 260.0000
# 最小值 (Min)    : 5.0000
# 标准差 (Std Dev): 28.5887
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-魔攻怪物(Magic)
# 描述: 霸者2级 vs 魔攻：魔攻无视反弹/霸体，只能靠输出速度。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 124.9757
# 【模拟均值】: 125.1060
# 【误差分析】: 绝对误差 0.1303 / 相对误差 0.10%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 125.1060
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 40.8677
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-普通怪物
# 描述: 霸者3级：反弹16%，霸体16%，破防11%。最强综合实力。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 22.6745
# 【模拟均值】: 22.7242
# 【误差分析】: 绝对误差 0.0497 / 相对误差 0.22%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 22.7242
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 120.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 13.5104
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-坚固怪物(Solid)
# 描述: 霸者3级 + 坚固：破防+11%可突破坚固防御，测试输出提升。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 216.5228
# 【模拟均值】: 217.6343
# 【误差分析】: 绝对误差 1.1115 / 相对误差 0.51%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 217.6343
# 中位数 (Median) : 205.0000
# 最大值 (Max)    : 790.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 109.6436
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-仿攻怪物(Mimic)
# 描述: 霸者3级 + 仿攻：反弹伤害=m_atk/3，可能造成秒杀。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 41.1869
# 【模拟均值】: 41.1474
# 【误差分析】: 绝对误差 0.0395 / 相对误差 0.10%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 41.1474
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 24.3641
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-K连击(k=4)
# 描述: 霸者3级 + 连击(k=4)：破防+高反弹+霸体，极致耐久与输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 95.8761
# 【模拟均值】: 96.1209
# 【误差分析】: 绝对误差 0.2448 / 相对误差 0.26%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 96.1209
# 中位数 (Median) : 93.0000
# 最大值 (Max)    : 273.0000
# 最小值 (Min)    : 6.0000
# 标准差 (Std Dev): 33.7501
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-魔攻怪物(Magic)
# 描述: 霸者3级 vs 魔攻：魔攻无视反弹/霸体，但破防11%仍有效。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 113.7815
# 【模拟均值】: 114.1540
# 【误差分析】: 绝对误差 0.3725 / 相对误差 0.33%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 114.1540
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 360.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 42.7493
# ------------------------------

# %% [markdown]
# # 贤者之证测试

# %%
# ====== 贤者之证 1级 测试 ======
run_test_case(
    title="贤者1级-普通怪物",
    description="贤者1级：闪避61%，集能减伤50点+随机回血。测试基础防御与集能机制。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-坚固怪物(Solid)",
    description="贤者1级 + 坚固：集能减伤50点对高防的影响有限，闪避更重要。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-仿攻怪物(Mimic)",
    description="贤者1级 + 仿攻：闪避对高伤害的减轻效果显著。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-K连击(k=2)",
    description="贤者1级 + 连击(k=2)：多次攻击中闪避可能多次触发，减伤累积。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-魔攻怪物(Magic)",
    description="贤者1级 vs 魔攻：魔攻无视闪避/集能，测试最坏情况。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

# ====== 贤者之证 2级 测试 ======
run_test_case(
    title="贤者2级-普通怪物",
    description="贤者2级：闪避81%，集能减伤100点+随机回血。防御力大幅提升。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-坚固怪物(Solid)",
    description="贤者2级 + 坚固：集能减伤100点对比1级翻倍，但坚固防御仍可能胜出。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-仿攻怪物(Mimic)",
    description="贤者2级 + 仿攻：高闪避(81%)对仿攻威胁大幅减弱。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-K连击(k=3)",
    description="贤者2级 + 连击(k=3)：高闪避+高集能减伤，连击伤害被极度削弱。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-魔攻怪物(Magic)",
    description="贤者2级 vs 魔攻：魔攻无视防御，但集能减伤100仍有基础保障。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

# ====== 贤者之证 3级 测试 ======
run_test_case(
    title="贤者3级-普通怪物",
    description="贤者3级：闪避100%（无法被击中），集能减伤100点+随机回血。终极防御。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-坚固怪物(Solid)",
    description="贤者3级 + 坚固：完全闪避(100%)使坚固防御失效，贤者绝对优势。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-仿攻怪物(Mimic)",
    description="贤者3级 + 仿攻：完全闪避使仿攻无威胁，集能减伤兜底。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-K连击(k=4)",
    description="贤者3级 + 连击(k=4)：完全闪避+集能减伤100，连击完全无效。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-魔攻怪物(Magic)",
    description="贤者3级 vs 魔攻：完全闪避对魔攻无效，但集能减伤100仍提供保护。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 贤者1级-普通怪物
# 描述: 贤者1级：闪避61%，集能减伤50点+随机回血。测试基础防御与集能机制。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 35.3136
# 【模拟均值】: 35.2791
# 【误差分析】: 绝对误差 0.0345 / 相对误差 0.10%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 35.2791
# 中位数 (Median) : 36.0000
# 最大值 (Max)    : 108.0000
# 最小值 (Min)    : -18.0000
# 标准差 (Std Dev): 14.2120
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-坚固怪物(Solid)
# 描述: 贤者1级 + 坚固：集能减伤50点对高防的影响有限，闪避更重要。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1762.3062
# 【模拟均值】: 1763.2941
# 【误差分析】: 绝对误差 0.9879 / 相对误差 0.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1763.2941
# 中位数 (Median) : 1764.0000
# 最大值 (Max)    : 2169.0000
# 最小值 (Min)    : 1368.0000
# 标准差 (Std Dev): 98.8741
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-仿攻怪物(Mimic)
# 描述: 贤者1级 + 仿攻：闪避对高伤害的减轻效果显著。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 52.2000
# 【模拟均值】: 52.2667
# 【误差分析】: 绝对误差 0.0667 / 相对误差 0.13%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 52.2667
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 17.3107
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-K连击(k=2)
# 描述: 贤者1级 + 连击(k=2)：多次攻击中闪避可能多次触发，减伤累积。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 77.4846
# 【模拟均值】: 77.5913
# 【误差分析】: 绝对误差 0.1067 / 相对误差 0.14%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 77.5913
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 180.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 21.9073
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-魔攻怪物(Magic)
# 描述: 贤者1级 vs 魔攻：魔攻无视闪避/集能，测试最坏情况。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 124.2114
# 【模拟均值】: 124.4028
# 【误差分析】: 绝对误差 0.1914 / 相对误差 0.15%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 124.4028
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : -16.0000
# 标准差 (Std Dev): 41.7323
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-普通怪物
# 描述: 贤者2级：闪避81%，集能减伤100点+随机回血。防御力大幅提升。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 14.3868
# 【模拟均值】: 13.9466
# 【误差分析】: 绝对误差 0.4402 / 相对误差 3.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 13.9466
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 108.0000
# 最小值 (Min)    : -219.0000
# 标准差 (Std Dev): 37.9675
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-坚固怪物(Solid)
# 描述: 贤者2级 + 坚固：集能减伤100点对比1级翻倍，但坚固防御仍可能胜出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 934.8700
# 【模拟均值】: 935.1376
# 【误差分析】: 绝对误差 0.2676 / 相对误差 0.03%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 935.1376
# 中位数 (Median) : 945.0000
# 最大值 (Max)    : 1813.0000
# 最小值 (Min)    : -150.0000
# 标准差 (Std Dev): 247.1195
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-仿攻怪物(Mimic)
# 描述: 贤者2级 + 仿攻：高闪避(81%)对仿攻威胁大幅减弱。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 45.8145
# 【模拟均值】: 45.7332
# 【误差分析】: 绝对误差 0.0813 / 相对误差 0.18%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 45.7332
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : -21.0000
# 标准差 (Std Dev): 24.7549
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-K连击(k=3)
# 描述: 贤者2级 + 连击(k=3)：高闪避+高集能减伤，连击伤害被极度削弱。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 34.5093
# 【模拟均值】: 33.9010
# 【误差分析】: 绝对误差 0.6084 / 相对误差 1.76%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 33.9010
# 中位数 (Median) : 44.0000
# 最大值 (Max)    : 315.0000
# 最小值 (Min)    : -373.0000
# 标准差 (Std Dev): 75.6308
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-魔攻怪物(Magic)
# 描述: 贤者2级 vs 魔攻：魔攻无视防御，但集能减伤100仍有基础保障。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 123.9608
# 【模拟均值】: 123.5092
# 【误差分析】: 绝对误差 0.4516 / 相对误差 0.36%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 123.5092
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 360.0000
# 最小值 (Min)    : -16.0000
# 标准差 (Std Dev): 41.9606
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-普通怪物
# 描述: 贤者3级：闪避100%（无法被击中），集能减伤100点+随机回血。终极防御。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -23.5131
# 【模拟均值】: -24.2620
# 【误差分析】: 绝对误差 0.7490 / 相对误差 3.19%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -24.2620
# 中位数 (Median) : -23.0000
# 最大值 (Max)    : 96.0000
# 最小值 (Min)    : -300.0000
# 标准差 (Std Dev): 55.6137
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-坚固怪物(Solid)
# 描述: 贤者3级 + 坚固：完全闪避(100%)使坚固防御失效，贤者绝对优势。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -562.9377
# 【模拟均值】: -556.4174
# 【误差分析】: 绝对误差 6.5204 / 相对误差 1.16%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -556.4174
# 中位数 (Median) : -549.0000
# 最大值 (Max)    : 802.0000
# 最小值 (Min)    : -2035.0000
# 标准差 (Std Dev): 355.2016
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-仿攻怪物(Mimic)
# 描述: 贤者3级 + 仿攻：完全闪避使仿攻无威胁，集能减伤兜底。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 34.2045
# 【模拟均值】: 33.9799
# 【误差分析】: 绝对误差 0.2246 / 相对误差 0.66%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 33.9799
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : -21.0000
# 标准差 (Std Dev): 30.8302
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-K连击(k=4)
# 描述: 贤者3级 + 连击(k=4)：完全闪避+集能减伤100，连击完全无效。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -151.4662
# 【模拟均值】: -152.6739
# 【误差分析】: 绝对误差 1.2077 / 相对误差 0.80%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -152.6739
# 中位数 (Median) : -143.0000
# 最大值 (Max)    : 213.0000
# 最小值 (Min)    : -826.0000
# 标准差 (Std Dev): 134.0110
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-魔攻怪物(Magic)
# 描述: 贤者3级 vs 魔攻：完全闪避对魔攻无效，但集能减伤100仍提供保护。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 27.1791
# 【模拟均值】: 26.9218
# 【误差分析】: 绝对误差 0.2573 / 相对误差 0.95%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 26.9218
# 中位数 (Median) : 48.0000
# 最大值 (Max)    : 320.0000
# 最小值 (Min)    : -448.0000
# 标准差 (Std Dev): 110.3967
# ------------------------------

# %%
run_test_case(
    title="贤者2级-普通怪物",
    description="贤者2级：闪避81%，集能减伤100点+随机回血。防御力大幅提升。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 2
    },
    n_trials=1000000
)
# Out:
# ============================================================
# 测试案例: 贤者2级-普通怪物
# 描述: 贤者2级：闪避81%，集能减伤100点+随机回血。防御力大幅提升。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 14.3868
# 【模拟均值】: 14.4313
# 【误差分析】: 绝对误差 0.0445 / 相对误差 0.31%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 1000000
# 平均值 (Mean)   : 14.4313
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 132.0000
# 最小值 (Min)    : -348.0000
# 标准差 (Std Dev): 37.5169
# ------------------------------

# %%
run_test_case(
    title="贤者3级-普通怪物",
    description="贤者3级：闪避100%（无法被击中），集能减伤100点+随机回血。终极防御。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 3
    },
    n_trials=1000000
)
# Out:
# ============================================================
# 测试案例: 贤者3级-普通怪物
# 描述: 贤者3级：闪避100%（无法被击中），集能减伤100点+随机回血。终极防御。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -23.5131
# 【模拟均值】: -23.5503
# 【误差分析】: 绝对误差 0.0373 / 相对误差 0.16%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 1000000
# 平均值 (Mean)   : -23.5503
# 中位数 (Median) : -23.0000
# 最大值 (Max)    : 132.0000
# 最小值 (Min)    : -396.0000
# 标准差 (Std Dev): 55.3316
# ------------------------------

# %%
run_test_case(
    title="贤者3级-魔攻怪物(Magic)",
    description="贤者3级 vs 魔攻：完全闪避对魔攻无效，但集能减伤100仍提供保护。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 3
    },
    n_trials=1000000
)
# Out:
# ============================================================
# 测试案例: 贤者3级-魔攻怪物(Magic)
# 描述: 贤者3级 vs 魔攻：完全闪避对魔攻无效，但集能减伤100仍提供保护。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 27.1791
# 【模拟均值】: 27.2741
# 【误差分析】: 绝对误差 0.0950 / 相对误差 0.35%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 1000000
# 平均值 (Mean)   : 27.2741
# 中位数 (Median) : 52.0000
# 最大值 (Max)    : 440.0000
# 最小值 (Min)    : -644.0000
# 标准差 (Std Dev): 110.4873
# ------------------------------

# %% [markdown]
# # 勇者之证测试

# %%
# ====== 勇者之证 1级 测试 ======
run_test_case(
    title="勇者1级-普通怪物",
    description="勇者1级：无特殊效果。测试基础数值。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-坚固怪物(Solid)",
    description="勇者1级 + 坚固：无攻击增益，防御压力大。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-仿攻怪物(Mimic)",
    description="勇者1级 + 仿攻：没有攻击加成，容易被反伤。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-K连击(k=2)",
    description="勇者1级 + 连击(k=2)：无加成，伤害压力大。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-魔攻怪物(Magic)",
    description="勇者1级 vs 魔攻：无特殊对抗能力。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

# ====== 勇者之证 2级 测试 ======
run_test_case(
    title="勇者2级-普通怪物",
    description="勇者2级：每回合2次攻击。伤害输出翻倍。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-坚固怪物(Solid)",
    description="勇者2级 + 坚固：2次攻击可能击穿或触发暴击。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-仿攻怪物(Mimic)",
    description="勇者2级 + 仿攻：2次高伤害输出对阵反伤。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-K连击(k=3)",
    description="勇者2级 + 连击(k=3)：2次vs 3次，频率竞争。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-魔攻怪物(Magic)",
    description="勇者2级 vs 魔攻：2次攻击应对魔攻伤害。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

# ====== 勇者之证 3级 测试 ======
run_test_case(
    title="勇者3级-普通怪物",
    description="勇者3级：每回合2次攻击+16%额外伤害。最强输出。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-坚固怪物(Solid)",
    description="勇者3级 + 坚固：额外伤害加成可能突破坚固防御。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-仿攻怪物(Mimic)",
    description="勇者3级 + 仿攻：2次高伤害+加成vs反伤，输出优势明显。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-K连击(k=4)",
    description="勇者3级 + 连击(k=4)：2次高伤害+加成vs 4次连击。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-魔攻怪物(Magic)",
    description="勇者3级 vs 魔攻：2次攻击+加成应对无视防御伤害。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 勇者1级-普通怪物
# 描述: 勇者1级：无特殊效果。测试基础数值。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 358.3653
# 【模拟均值】: 357.5520
# 【误差分析】: 绝对误差 0.8133 / 相对误差 0.23%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 357.5520
# 中位数 (Median) : 360.0000
# 最大值 (Max)    : 1320.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 137.8478
# ------------------------------
# ============================================================
# 测试案例: 勇者1级-坚固怪物(Solid)
# 描述: 勇者1级 + 坚固：无攻击增益，防御压力大。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 179855.6902
# 【模拟均值】: 179851.7325
# 【误差分析】: 绝对误差 3.9577 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 179851.7325
# 中位数 (Median) : 179850.0000
# 最大值 (Max)    : 192300.0000
# 最小值 (Min)    : 167700.0000
# 标准差 (Std Dev): 3039.1404
# ------------------------------
# ============================================================
# 测试案例: 勇者1级-仿攻怪物(Mimic)
# 描述: 勇者1级 + 仿攻：没有攻击加成，容易被反伤。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 522.0000
# 【模拟均值】: 521.0720
# 【误差分析】: 绝对误差 0.9280 / 相对误差 0.18%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 521.0720
# 中位数 (Median) : 580.0000
# 最大值 (Max)    : 580.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 175.2305
# ------------------------------
# ============================================================
# 测试案例: 勇者1级-K连击(k=2)
# 描述: 勇者1级 + 连击(k=2)：无加成，伤害压力大。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 785.8147
# 【模拟均值】: 786.4700
# 【误差分析】: 绝对误差 0.6553 / 相对误差 0.08%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 786.4700
# 中位数 (Median) : 800.0000
# 最大值 (Max)    : 1800.0000
# 最小值 (Min)    : 200.0000
# 标准差 (Std Dev): 214.4060
# ------------------------------
# ============================================================
# 测试案例: 勇者1级-魔攻怪物(Magic)
# 描述: 勇者1级 vs 魔攻：无特殊对抗能力。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1249.7567
# 【模拟均值】: 1253.7000
# 【误差分析】: 绝对误差 3.9433 / 相对误差 0.32%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1253.7000
# 中位数 (Median) : 1200.0000
# 最大值 (Max)    : 4000.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 408.3777
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-普通怪物
# 描述: 勇者2级：每回合2次攻击。伤害输出翻倍。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 147.4927
# 【模拟均值】: 148.0620
# 【误差分析】: 绝对误差 0.5693 / 相对误差 0.39%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 148.0620
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 720.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 77.6173
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-坚固怪物(Solid)
# 描述: 勇者2级 + 坚固：2次攻击可能击穿或触发暴击。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 89886.8764
# 【模拟均值】: 89877.0975
# 【误差分析】: 绝对误差 9.7789 / 相对误差 0.01%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 89877.0975
# 中位数 (Median) : 89850.0000
# 最大值 (Max)    : 97500.0000
# 最小值 (Min)    : 82800.0000
# 标准差 (Std Dev): 1824.5076
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-仿攻怪物(Mimic)
# 描述: 勇者2级 + 仿攻：2次高伤害输出对阵反伤。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 0.0000
# 【模拟均值】: 0.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 nan%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 0.0000
# 中位数 (Median) : 0.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-K连击(k=3)
# 描述: 勇者2级 + 连击(k=3)：2次vs 3次，频率竞争。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 509.6890
# 【模拟均值】: 511.7250
# 【误差分析】: 绝对误差 2.0360 / 相对误差 0.40%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 511.7250
# 中位数 (Median) : 500.0000
# 最大值 (Max)    : 1500.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 196.3238
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-魔攻怪物(Magic)
# 描述: 勇者2级 vs 魔攻：2次攻击应对魔攻伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 506.1334
# 【模拟均值】: 504.4400
# 【误差分析】: 绝对误差 1.6934 / 相对误差 0.33%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 504.4400
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 2400.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 241.9675
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-普通怪物
# 描述: 勇者3级：每回合2次攻击+16%额外伤害。最强输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 146.5288
# 【模拟均值】: 146.4660
# 【误差分析】: 绝对误差 0.0628 / 相对误差 0.04%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 146.4660
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 600.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 78.7814
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-坚固怪物(Solid)
# 描述: 勇者3级 + 坚固：额外伤害加成可能突破坚固防御。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 89886.8764
# 【模拟均值】: 89869.2975
# 【误差分析】: 绝对误差 17.5789 / 相对误差 0.02%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 89869.2975
# 中位数 (Median) : 89850.0000
# 最大值 (Max)    : 97050.0000
# 最小值 (Min)    : 81750.0000
# 标准差 (Std Dev): 1843.0929
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-仿攻怪物(Mimic)
# 描述: 勇者3级 + 仿攻：2次高伤害+加成vs反伤，输出优势明显。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 0.0000
# 【模拟均值】: 0.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 nan%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 0.0000
# 中位数 (Median) : 0.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-K连击(k=4)
# 描述: 勇者3级 + 连击(k=4)：2次高伤害+加成vs 4次连击。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 675.5472
# 【模拟均值】: 675.9450
# 【误差分析】: 绝对误差 0.3978 / 相对误差 0.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 675.9450
# 中位数 (Median) : 700.0000
# 最大值 (Max)    : 1800.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 253.0946
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-魔攻怪物(Magic)
# 描述: 勇者3级 vs 魔攻：2次攻击+加成应对无视防御伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 506.1334
# 【模拟均值】: 505.4600
# 【误差分析】: 绝对误差 0.6734 / 相对误差 0.13%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 505.4600
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 2000.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 240.9776
# ------------------------------

# %% [markdown]
# # 随便测试

# %%
run_test_case(
    title="随便测试",
    description="随便测试",
    sim_params={
        'm_hp': 6236, 'm_atk': 646, 'm_def': 442, 'm_eva': 0.56, 'm_crit': 0.66,
        'h_atk': 524, 'h_def': 140, 'h_eva': 0.63, 'h_crit': 0.26,'h_atk_thresh': 5,'h_def_thresh':2,
        'emblem_type': 'sage', 'emblem_level': 3,
        'special_type':'k_combo','k_value':8
    },
    n_trials=10000
)
# Out:
# ============================================================
# 测试案例: 随便测试
# 描述: 随便测试
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 6236
#   攻击力(ATK): 646
#   防御力(DEF): 442
#   闪避率(EVA): 0.56
#   暴击率(CRIT): 0.66
# 【勇士属性】
#   攻击力(ATK): 524
#   防御力(DEF): 140
#   闪避率(EVA): 0.63
#   暴击率(CRIT): 0.26
# 【临界值】: 攻击 5, 防御 2
# 【特殊能力】: k_combo
#   连击次数: 8
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 241494.5100
# 【模拟均值】: 241380.7767
# 【误差分析】: 绝对误差 113.7333 / 相对误差 0.05%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 10000
# 平均值 (Mean)   : 241380.7767
# 中位数 (Median) : 240185.5000
# 最大值 (Max)    : 358745.0000
# 最小值 (Min)    : 146693.0000
# 标准差 (Std Dev): 29865.4383
# ------------------------------
