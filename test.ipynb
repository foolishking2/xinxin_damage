# %%
from damage import run_test_case

# %% [markdown]
# # 无章测试

# %%
run_test_case(
    title="基础数学验证 (无概率)",
    description="验证基础伤害扣减和回合数计算是否准确 (预期伤害 40)。",
    sim_params={
        'm_hp': 100, 'm_atk': 20, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 30, 'h_def': 10, 'h_eva': 0, 'h_crit': 0
    }
)

run_test_case(
    title="临界值 1点伤害测试",
    description="勇士不破防，但达到攻击临界值，造成强制1点伤害。",
    sim_params={
        'm_hp': 5, 'm_atk': 100, 'm_def': 50, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 50, 'h_def': 0, 'h_eva': 0, 'h_crit': 0,
        'h_atk_thresh': 5
    }
)

run_test_case(
    title="坚固怪物 (Solid) + 50% 暴击",
    description="怪物防御自动调整为勇士攻击力，依赖临界值和暴击输出。",
    sim_params={
        'm_hp': 15, 'm_atk': 50, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 100, 'h_def': 40, 'h_eva': 0, 'h_crit': 0.5,
        'h_atk_thresh': 10, 'special_type': 'solid'
    },
    n_trials=50000 # 增加次数以稳定结果
)

run_test_case(
    title="魔攻怪物 (Magic) + 50% 闪避",
    description="勇士防御极高但被魔攻无视，依靠50%闪避减少伤害。",
    sim_params={
        'm_hp': 100, 'm_atk': 50, 'm_def': 10, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 35, 'h_def': 1000, 'h_eva': 0.5, 'h_crit': 0,
        'special_type': 'magic'
    }
)

run_test_case(
    title="3连击怪物 (K-Combo)",
    description="怪物每回合攻击3次，测试高频攻击下的伤害累积。",
    sim_params={
        'm_hp': 200, 'm_atk': 20, 'm_def': 0, 'm_eva': 0.1, 'm_crit': 0.2,
        'h_atk': 30, 'h_def': 10, 'h_eva': 0.1, 'h_crit': 0.3,
        'special_type': 'k_combo', 'k_value': 3
    }
)

run_test_case(
    title="仿攻怪物 (Mimic)",
    description="怪物攻击力复制勇士攻击力，造成巨额伤害。",
    sim_params={
        'm_hp': 500, 'm_atk': 10, 'm_def': 100, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 200, 'h_def': 50, 'h_eva': 0, 'h_crit': 0,
        'special_type': 'mimic'
    }
)

run_test_case(
    title="无法击败测试 (NaN)",
    description="勇士攻击力不足且未达临界值，预期返回 NaN。",
    sim_params={
        'm_hp': 100, 'm_atk': 10, 'm_def': 100, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 10, 'h_def': 10, 'h_eva': 0, 'h_crit': 0,
        'h_atk_thresh': 0
    },
    n_trials=100
)
# Out:
# ============================================================
# 测试案例: 基础数学验证 (无概率)
# 描述: 验证基础伤害扣减和回合数计算是否准确 (预期伤害 40)。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 20
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 30
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 40.0000
# 【模拟均值】: 40.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 40.0000
# 中位数 (Median) : 40.0000
# 最大值 (Max)    : 40.0000
# 最小值 (Min)    : 40.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 临界值 1点伤害测试
# 描述: 勇士不破防，但达到攻击临界值，造成强制1点伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 5
#   攻击力(ATK): 100
#   防御力(DEF): 50
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 0
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 5, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 400.0000
# 【模拟均值】: 400.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 400.0000
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : 400.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 坚固怪物 (Solid) + 50% 暴击
# 描述: 怪物防御自动调整为勇士攻击力，依赖临界值和暴击输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 15
#   攻击力(ATK): 50
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 100
#   防御力(DEF): 40
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.5
# 【临界值】: 攻击 10, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 92.2223
# 【模拟均值】: 92.2746
# 【误差分析】: 绝对误差 0.0523 / 相对误差 0.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 50000
# 平均值 (Mean)   : 92.2746
# 中位数 (Median) : 90.0000
# 最大值 (Max)    : 140.0000
# 最小值 (Min)    : 70.0000
# 标准差 (Std Dev): 10.6303
# ------------------------------
# ============================================================
# 测试案例: 魔攻怪物 (Magic) + 50% 闪避
# 描述: 勇士防御极高但被魔攻无视，依靠50%闪避减少伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 50
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 35
#   防御力(DEF): 1000
#   闪避率(EVA): 0.5
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 75.0000
# 【模拟均值】: 75.3400
# 【误差分析】: 绝对误差 0.3400 / 相对误差 0.45%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 75.3400
# 中位数 (Median) : 100.0000
# 最大值 (Max)    : 150.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 43.5561
# ------------------------------
# ============================================================
# 测试案例: 3连击怪物 (K-Combo)
# 描述: 怪物每回合攻击3次，测试高频攻击下的伤害累积。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 200
#   攻击力(ATK): 20
#   防御力(DEF): 0
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.2
# 【勇士属性】
#   攻击力(ATK): 30
#   防御力(DEF): 10
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.3
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 167.8381
# 【模拟均值】: 168.1895
# 【误差分析】: 绝对误差 0.3514 / 相对误差 0.21%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 168.1895
# 中位数 (Median) : 160.0000
# 最大值 (Max)    : 420.0000
# 最小值 (Min)    : 50.0000
# 标准差 (Std Dev): 45.0921
# ------------------------------
# ============================================================
# 测试案例: 仿攻怪物 (Mimic)
# 描述: 怪物攻击力复制勇士攻击力，造成巨额伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 500
#   攻击力(ATK): 10
#   防御力(DEF): 100
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 200
#   防御力(DEF): 50
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: 600.0000
# 【模拟均值】: 600.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 600.0000
# 中位数 (Median) : 600.0000
# 最大值 (Max)    : 600.0000
# 最小值 (Min)    : 600.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 无法击败测试 (NaN)
# 描述: 勇士攻击力不足且未达临界值，预期返回 NaN。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 10
#   防御力(DEF): 100
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 10
#   防御力(DEF): 10
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: None (等级 0)
# ------------------------------------------------------------
# 【公式预期】: NaN (无法击败)
# 【模拟结果】: NaN (无法击败)

# %% [markdown]
# # 霸者之证测试

# %%
# ====== 霸者之证 1级 测试 ======
run_test_case(
    title="霸者1级-普通怪物",
    description="霸者1级：反弹概率6%，无霸体。测试基础反弹机制。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-坚固怪物(Solid)",
    description="霸者1级 + 坚固怪物：测试反弹与坚固属性交互。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-仿攻怪物(Mimic)",
    description="霸者1级 + 仿攻：怪物攻击被复制，反弹伤害=original_dmg/2。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-K连击(k=2)",
    description="霸者1级 + 连击(k=2)：每回合2次攻击，反弹可能被多次触发。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

run_test_case(
    title="霸者1级-魔攻怪物(Magic)",
    description="霸者1级 vs 魔攻：魔攻无视反弹/霸体，反弹不触发。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 1
    }
)

# ====== 霸者之证 2级 测试 ======
run_test_case(
    title="霸者2级-普通怪物",
    description="霸者2级：反弹概率11%，霸体概率11%。测试反弹与霸体组合。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-坚固怪物(Solid)",
    description="霸者2级 + 坚固：霸体加倍防御可能被触发，影响伤害计算。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-仿攻怪物(Mimic)",
    description="霸者2级 + 仿攻：反弹伤害=original_dmg（2级提升），可能瞬杀。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-K连击(k=3)",
    description="霸者2级 + 连击(k=3)：高频反弹/霸体触发，测试耐久性。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

run_test_case(
    title="霸者2级-魔攻怪物(Magic)",
    description="霸者2级 vs 魔攻：魔攻无视反弹/霸体，只能靠输出速度。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 2
    }
)

# ====== 霸者之证 3级 测试 ======
run_test_case(
    title="霸者3级-普通怪物",
    description="霸者3级：反弹16%，霸体16%，破防11%。最强综合实力。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-坚固怪物(Solid)",
    description="霸者3级 + 坚固：破防+11%可突破坚固防御，测试输出提升。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-仿攻怪物(Mimic)",
    description="霸者3级 + 仿攻：反弹伤害=m_atk/3，可能造成秒杀。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-K连击(k=4)",
    description="霸者3级 + 连击(k=4)：破防+高反弹+霸体，极致耐久与输出。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)

run_test_case(
    title="霸者3级-魔攻怪物(Magic)",
    description="霸者3级 vs 魔攻：魔攻无视反弹/霸体，但破防11%仍有效。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'overlord', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 霸者1级-普通怪物
# 描述: 霸者1级：反弹概率6%，无霸体。测试基础反弹机制。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 35.5237
# 【模拟均值】: 35.5590
# 【误差分析】: 绝对误差 0.0353 / 相对误差 0.10%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 35.5590
# 中位数 (Median) : 36.0000
# 最大值 (Max)    : 120.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 13.5520
# ------------------------------
# ============================================================
# 测试案例: 霸者1级-坚固怪物(Solid)
# 描述: 霸者1级 + 坚固怪物：测试反弹与坚固属性交互。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1259.2780
# 【模拟均值】: 1262.3280
# 【误差分析】: 绝对误差 3.0500 / 相对误差 0.24%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1262.3280
# 中位数 (Median) : 1260.0000
# 最大值 (Max)    : 2100.0000
# 最小值 (Min)    : 540.0000
# 标准差 (Std Dev): 186.8588
# ------------------------------
# ============================================================
# 测试案例: 霸者1级-仿攻怪物(Mimic)
# 描述: 霸者1级 + 仿攻：怪物攻击被复制，反弹伤害=original_dmg/2。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 49.0680
# 【模拟均值】: 48.9752
# 【误差分析】: 绝对误差 0.0928 / 相对误差 0.19%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 48.9752
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 21.0236
# ------------------------------
# ============================================================
# 测试案例: 霸者1级-K连击(k=2)
# 描述: 霸者1级 + 连击(k=2)：每回合2次攻击，反弹可能被多次触发。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 76.8717
# 【模拟均值】: 77.0025
# 【误差分析】: 绝对误差 0.1308 / 相对误差 0.17%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 77.0025
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 190.0000
# 最小值 (Min)    : 10.0000
# 标准差 (Std Dev): 21.2807
# ------------------------------
# ============================================================
# 测试案例: 霸者1级-魔攻怪物(Magic)
# 描述: 霸者1级 vs 魔攻：魔攻无视反弹/霸体，反弹不触发。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 124.9757
# 【模拟均值】: 124.7080
# 【误差分析】: 绝对误差 0.2677 / 相对误差 0.21%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 124.7080
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 440.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 40.9985
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-普通怪物
# 描述: 霸者2级：反弹概率11%，霸体概率11%。测试反弹与霸体组合。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 27.7978
# 【模拟均值】: 27.9468
# 【误差分析】: 绝对误差 0.1490 / 相对误差 0.54%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 27.9468
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 108.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 14.0041
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-坚固怪物(Solid)
# 描述: 霸者2级 + 坚固：霸体加倍防御可能被触发，影响伤害计算。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 637.9596
# 【模拟均值】: 639.4025
# 【误差分析】: 绝对误差 1.4429 / 相对误差 0.23%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 639.4025
# 中位数 (Median) : 617.0000
# 最大值 (Max)    : 1568.0000
# 最小值 (Min)    : 116.0000
# 标准差 (Std Dev): 183.5572
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-仿攻怪物(Mimic)
# 描述: 霸者2级 + 仿攻：反弹伤害=original_dmg（2级提升），可能瞬杀。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 44.5196
# 【模拟均值】: 44.4072
# 【误差分析】: 绝对误差 0.1124 / 相对误差 0.25%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 44.4072
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 23.1145
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-K连击(k=3)
# 描述: 霸者2级 + 连击(k=3)：高频反弹/霸体触发，测试耐久性。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 83.1301
# 【模拟均值】: 82.8490
# 【误差分析】: 绝对误差 0.2811 / 相对误差 0.34%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 82.8490
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 220.0000
# 最小值 (Min)    : 5.0000
# 标准差 (Std Dev): 28.2759
# ------------------------------
# ============================================================
# 测试案例: 霸者2级-魔攻怪物(Magic)
# 描述: 霸者2级 vs 魔攻：魔攻无视反弹/霸体，只能靠输出速度。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 124.9757
# 【模拟均值】: 125.1040
# 【误差分析】: 绝对误差 0.1283 / 相对误差 0.10%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 125.1040
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 360.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 40.6156
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-普通怪物
# 描述: 霸者3级：反弹16%，霸体16%，破防11%。最强综合实力。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 22.6745
# 【模拟均值】: 22.7136
# 【误差分析】: 绝对误差 0.0391 / 相对误差 0.17%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 22.7136
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 108.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 13.5577
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-坚固怪物(Solid)
# 描述: 霸者3级 + 坚固：破防+11%可突破坚固防御，测试输出提升。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 216.5228
# 【模拟均值】: 217.9077
# 【误差分析】: 绝对误差 1.3850 / 相对误差 0.64%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 217.9077
# 中位数 (Median) : 205.0000
# 最大值 (Max)    : 800.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 111.7835
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-仿攻怪物(Mimic)
# 描述: 霸者3级 + 仿攻：反弹伤害=m_atk/3，可能造成秒杀。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 41.1869
# 【模拟均值】: 41.0505
# 【误差分析】: 绝对误差 0.1364 / 相对误差 0.33%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 41.0505
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 24.5222
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-K连击(k=4)
# 描述: 霸者3级 + 连击(k=4)：破防+高反弹+霸体，极致耐久与输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 95.8761
# 【模拟均值】: 95.8259
# 【误差分析】: 绝对误差 0.0502 / 相对误差 0.05%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 95.8259
# 中位数 (Median) : 93.0000
# 最大值 (Max)    : 263.0000
# 最小值 (Min)    : 6.0000
# 标准差 (Std Dev): 33.7825
# ------------------------------
# ============================================================
# 测试案例: 霸者3级-魔攻怪物(Magic)
# 描述: 霸者3级 vs 魔攻：魔攻无视反弹/霸体，但破防11%仍有效。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: overlord (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 113.7815
# 【模拟均值】: 114.1640
# 【误差分析】: 绝对误差 0.3825 / 相对误差 0.34%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 114.1640
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 400.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 42.0060
# ------------------------------

# %% [markdown]
# # 贤者之证测试

# %%
# ====== 贤者之证 1级 测试 ======
run_test_case(
    title="贤者1级-普通怪物",
    description="贤者1级：闪避61%，集能减伤50点+随机回血。测试基础防御与集能机制。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-坚固怪物(Solid)",
    description="贤者1级 + 坚固：集能减伤50点对高防的影响有限，闪避更重要。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-仿攻怪物(Mimic)",
    description="贤者1级 + 仿攻：闪避对高伤害的减轻效果显著。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-K连击(k=2)",
    description="贤者1级 + 连击(k=2)：多次攻击中闪避可能多次触发，减伤累积。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-魔攻怪物(Magic)",
    description="贤者1级 vs 魔攻：魔攻无视闪避/集能，测试最坏情况。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

# ====== 贤者之证 2级 测试 ======
run_test_case(
    title="贤者2级-普通怪物",
    description="贤者2级：闪避81%，集能减伤100点+随机回血。防御力大幅提升。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-坚固怪物(Solid)",
    description="贤者2级 + 坚固：集能减伤100点对比1级翻倍，但坚固防御仍可能胜出。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-仿攻怪物(Mimic)",
    description="贤者2级 + 仿攻：高闪避(81%)对仿攻威胁大幅减弱。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-K连击(k=3)",
    description="贤者2级 + 连击(k=3)：高闪避+高集能减伤，连击伤害被极度削弱。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-魔攻怪物(Magic)",
    description="贤者2级 vs 魔攻：魔攻无视防御，但集能减伤100仍有基础保障。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

# ====== 贤者之证 3级 测试 ======
run_test_case(
    title="贤者3级-普通怪物",
    description="贤者3级：闪避100%（无法被击中），集能减伤100点+随机回血。终极防御。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 18, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-坚固怪物(Solid)",
    description="贤者3级 + 坚固：完全闪避(100%)使坚固防御失效，贤者绝对优势。",
    sim_params={
        'm_hp': 120, 'm_atk': 35, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 20, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-仿攻怪物(Mimic)",
    description="贤者3级 + 仿攻：完全闪避使仿攻无威胁，集能减伤兜底。",
    sim_params={
        'm_hp': 80, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 22, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-K连击(k=4)",
    description="贤者3级 + 连击(k=4)：完全闪避+集能减伤100，连击完全无效。",
    sim_params={
        'm_hp': 150, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 15, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-魔攻怪物(Magic)",
    description="贤者3级 vs 魔攻：完全闪避对魔攻无效，但集能减伤100仍提供保护。",
    sim_params={
        'm_hp': 90, 'm_atk': 40, 'm_def': 12, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 40, 'h_def': 50, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'sage', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 贤者1级-普通怪物
# 描述: 贤者1级：闪避61%，集能减伤50点+随机回血。测试基础防御与集能机制。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 35.3136
# 【模拟均值】: 35.1264
# 【误差分析】: 绝对误差 0.1872 / 相对误差 0.53%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 35.1264
# 中位数 (Median) : 36.0000
# 最大值 (Max)    : 120.0000
# 最小值 (Min)    : -12.0000
# 标准差 (Std Dev): 14.1105
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-坚固怪物(Solid)
# 描述: 贤者1级 + 坚固：集能减伤50点对高防的影响有限，闪避更重要。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1762.3062
# 【模拟均值】: 1761.5122
# 【误差分析】: 绝对误差 0.7941 / 相对误差 0.05%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1761.5122
# 中位数 (Median) : 1758.0000
# 最大值 (Max)    : 2184.0000
# 最小值 (Min)    : 1369.0000
# 标准差 (Std Dev): 99.0950
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-仿攻怪物(Mimic)
# 描述: 贤者1级 + 仿攻：闪避对高伤害的减轻效果显著。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 52.2000
# 【模拟均值】: 52.0637
# 【误差分析】: 绝对误差 0.1363 / 相对误差 0.26%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 52.0637
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 17.5803
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-K连击(k=2)
# 描述: 贤者1级 + 连击(k=2)：多次攻击中闪避可能多次触发，减伤累积。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 77.4846
# 【模拟均值】: 77.4160
# 【误差分析】: 绝对误差 0.0686 / 相对误差 0.09%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 77.4160
# 中位数 (Median) : 80.0000
# 最大值 (Max)    : 210.0000
# 最小值 (Min)    : -5.0000
# 标准差 (Std Dev): 22.1805
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-魔攻怪物(Magic)
# 描述: 贤者1级 vs 魔攻：魔攻无视闪避/集能，测试最坏情况。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 124.2114
# 【模拟均值】: 123.8960
# 【误差分析】: 绝对误差 0.3154 / 相对误差 0.25%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 123.8960
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 360.0000
# 最小值 (Min)    : -16.0000
# 标准差 (Std Dev): 41.3563
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-普通怪物
# 描述: 贤者2级：闪避81%，集能减伤100点+随机回血。防御力大幅提升。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 14.3868
# 【模拟均值】: 14.4355
# 【误差分析】: 绝对误差 0.0487 / 相对误差 0.34%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 14.4355
# 中位数 (Median) : 24.0000
# 最大值 (Max)    : 144.0000
# 最小值 (Min)    : -219.0000
# 标准差 (Std Dev): 37.5514
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-坚固怪物(Solid)
# 描述: 贤者2级 + 坚固：集能减伤100点对比1级翻倍，但坚固防御仍可能胜出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 934.8700
# 【模拟均值】: 931.9361
# 【误差分析】: 绝对误差 2.9340 / 相对误差 0.31%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 931.9361
# 中位数 (Median) : 941.0000
# 最大值 (Max)    : 1734.0000
# 最小值 (Min)    : -104.0000
# 标准差 (Std Dev): 245.2658
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-仿攻怪物(Mimic)
# 描述: 贤者2级 + 仿攻：高闪避(81%)对仿攻威胁大幅减弱。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 45.8145
# 【模拟均值】: 45.6696
# 【误差分析】: 绝对误差 0.1449 / 相对误差 0.32%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 45.6696
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : -21.0000
# 标准差 (Std Dev): 24.7582
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-K连击(k=3)
# 描述: 贤者2级 + 连击(k=3)：高闪避+高集能减伤，连击伤害被极度削弱。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 34.5093
# 【模拟均值】: 35.1609
# 【误差分析】: 绝对误差 0.6515 / 相对误差 1.89%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 35.1609
# 中位数 (Median) : 45.0000
# 最大值 (Max)    : 255.0000
# 最小值 (Min)    : -483.0000
# 标准差 (Std Dev): 75.6627
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-魔攻怪物(Magic)
# 描述: 贤者2级 vs 魔攻：魔攻无视防御，但集能减伤100仍有基础保障。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 123.9608
# 【模拟均值】: 124.3944
# 【误差分析】: 绝对误差 0.4336 / 相对误差 0.35%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 124.3944
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 360.0000
# 最小值 (Min)    : -24.0000
# 标准差 (Std Dev): 41.6330
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-普通怪物
# 描述: 贤者3级：闪避100%（无法被击中），集能减伤100点+随机回血。终极防御。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 18
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -23.5131
# 【模拟均值】: -23.1791
# 【误差分析】: 绝对误差 0.3340 / 相对误差 1.42%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -23.1791
# 中位数 (Median) : -22.0000
# 最大值 (Max)    : 96.0000
# 最小值 (Min)    : -294.0000
# 标准差 (Std Dev): 54.9662
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-坚固怪物(Solid)
# 描述: 贤者3级 + 坚固：完全闪避(100%)使坚固防御失效，贤者绝对优势。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 120
#   攻击力(ATK): 35
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 20
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -562.9377
# 【模拟均值】: -565.8160
# 【误差分析】: 绝对误差 2.8782 / 相对误差 0.51%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -565.8160
# 中位数 (Median) : -559.0000
# 最大值 (Max)    : 751.0000
# 最小值 (Min)    : -2059.0000
# 标准差 (Std Dev): 351.6383
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-仿攻怪物(Mimic)
# 描述: 贤者3级 + 仿攻：完全闪避使仿攻无威胁，集能减伤兜底。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 80
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 22
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 34.2045
# 【模拟均值】: 33.9731
# 【误差分析】: 绝对误差 0.2314 / 相对误差 0.68%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 33.9731
# 中位数 (Median) : 58.0000
# 最大值 (Max)    : 58.0000
# 最小值 (Min)    : -21.0000
# 标准差 (Std Dev): 30.9670
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-K连击(k=4)
# 描述: 贤者3级 + 连击(k=4)：完全闪避+集能减伤100，连击完全无效。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 150
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 15
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -151.4662
# 【模拟均值】: -151.7500
# 【误差分析】: 绝对误差 0.2837 / 相对误差 0.19%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -151.7500
# 中位数 (Median) : -142.0000
# 最大值 (Max)    : 240.0000
# 最小值 (Min)    : -829.0000
# 标准差 (Std Dev): 133.0922
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-魔攻怪物(Magic)
# 描述: 贤者3级 vs 魔攻：完全闪避对魔攻无效，但集能减伤100仍提供保护。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 90
#   攻击力(ATK): 40
#   防御力(DEF): 12
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 40
#   防御力(DEF): 50
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 27.1791
# 【模拟均值】: 26.3318
# 【误差分析】: 绝对误差 0.8472 / 相对误差 3.12%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 26.3318
# 中位数 (Median) : 48.0000
# 最大值 (Max)    : 320.0000
# 最小值 (Min)    : -462.0000
# 标准差 (Std Dev): 109.9131
# ------------------------------

# %% [markdown]
# ## 贤者之证含有秒杀的测试

# %%
# ====== 贤者之证 1级 补充测试 ======
run_test_case(
    title="贤者1级-补充-零伤固防",
    description="贤者1级 + 坚固：勇士防御极高，结合集能减伤50点，使怪物伤害为0。",
    sim_params={
        'm_hp': 100, 'm_atk': 30, 'm_def': 15, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.2, # 极高防御
        'special_type': 'solid',
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

run_test_case(
    title="贤者1级-补充-零伤多击",
    description="贤者1级 + K连击(k=2)：勇士防御极高，保证怪物每次连击伤害均为0。",
    sim_params={
        'm_hp': 1500, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.18, # 极高防御
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'sage', 'emblem_level': 1
    }
)

# ====== 贤者之证 2级 补充测试 ======
run_test_case(
    title="贤者2级-补充-零伤仿攻",
    description="贤者2级 + 仿攻：勇士高防 + 集能减伤100点，应对仿攻的低基攻。",
    sim_params={
        'm_hp': 8000, 'm_atk': 15, 'm_def': 20, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 80, 'h_def': 500, 'h_eva': 0.3, 'h_crit': 0.1, # 极高防御
        'special_type': 'mimic',
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

run_test_case(
    title="贤者2级-补充-零伤高攻",
    description="贤者2级：集能减伤100点，配合闪避和防御，抵消较高攻击力的怪物。",
    sim_params={
        'm_hp': 1200, 'm_atk': 120, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 50, 'h_def': 250, 'h_eva': 0.3, 'h_crit': 0.15,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'sage', 'emblem_level': 2
    }
)

# ====== 贤者之证 3级 补充测试 ======
run_test_case(
    title="贤者3级-补充-零伤连击",
    description="贤者3级 + K连击(k=4)：100%闪避确保怪物无法命中，集能减伤100为理论零伤提供支持。",
    sim_params={
        'm_hp': 1500, 'm_atk': 25, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 45, 'h_def': 150, 'h_eva': 0.35, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'sage', 'emblem_level': 3
    }
)

run_test_case(
    title="贤者3级-补充-零伤极限高攻",
    description="贤者3级：100%闪避直接判定为零伤害，但仍验证集能减伤100对高攻的保障。",
    sim_params={
        'm_hp': 2000, 'm_atk': 500, 'm_def': 10, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 550, 'h_def': 2500, 'h_eva': 0.45, 'h_crit': 0.15,
        # 勇士攻击远大于怪物防御，战斗结束；怪物攻击极高，但会被100%闪避完全抵消
        'emblem_type': 'sage', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 贤者1级-补充-零伤固防
# 描述: 贤者1级 + 坚固：勇士防御极高，结合集能减伤50点，使怪物伤害为0。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 100
#   攻击力(ATK): 30
#   防御力(DEF): 15
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: -100.7381
# 【模拟均值】: -100.9290
# 【误差分析】: 绝对误差 0.1909 / 相对误差 0.19%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -100.9290
# 中位数 (Median) : -102.0000
# 最大值 (Max)    : -18.0000
# 最小值 (Min)    : -204.0000
# 标准差 (Std Dev): 22.8574
# ------------------------------
# ============================================================
# 测试案例: 贤者1级-补充-零伤多击
# 描述: 贤者1级 + K连击(k=2)：勇士防御极高，保证怪物每次连击伤害均为0。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 500
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: sage (等级 1)
# ------------------------------------------------------------
# 【公式预期】: -8.1683
# 【模拟均值】: -8.1690
# 【误差分析】: 绝对误差 0.0007 / 相对误差 0.01%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -8.1690
# 中位数 (Median) : -5.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -100.0000
# 标准差 (Std Dev): 10.3463
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-补充-零伤仿攻
# 描述: 贤者2级 + 仿攻：勇士高防 + 集能减伤100点，应对仿攻的低基攻。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 8000
#   攻击力(ATK): 15
#   防御力(DEF): 20
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 80
#   防御力(DEF): 500
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: -34.7143
# 【模拟均值】: -34.9944
# 【误差分析】: 绝对误差 0.2801 / 相对误差 0.81%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -34.9944
# 中位数 (Median) : -16.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -416.0000
# 标准差 (Std Dev): 41.6821
# ------------------------------
# ============================================================
# 测试案例: 贤者2级-补充-零伤高攻
# 描述: 贤者2级：集能减伤100点，配合闪避和防御，抵消较高攻击力的怪物。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 120
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 50
#   防御力(DEF): 250
#   闪避率(EVA): 0.3
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: sage (等级 2)
# ------------------------------------------------------------
# 【公式预期】: -52.0662
# 【模拟均值】: -52.1544
# 【误差分析】: 绝对误差 0.0882 / 相对误差 0.17%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -52.1544
# 中位数 (Median) : -24.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -672.0000
# 标准差 (Std Dev): 62.6811
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-补充-零伤连击
# 描述: 贤者3级 + K连击(k=4)：100%闪避确保怪物无法命中，集能减伤100为理论零伤提供支持。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 25
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 45
#   防御力(DEF): 150
#   闪避率(EVA): 0.35
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -16.8269
# 【模拟均值】: -16.9202
# 【误差分析】: 绝对误差 0.0933 / 相对误差 0.55%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -16.9202
# 中位数 (Median) : -10.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -210.0000
# 标准差 (Std Dev): 19.2642
# ------------------------------
# ============================================================
# 测试案例: 贤者3级-补充-零伤极限高攻
# 描述: 贤者3级：100%闪避直接判定为零伤害，但仍验证集能减伤100对高攻的保障。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 2000
#   攻击力(ATK): 500
#   防御力(DEF): 10
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 550
#   防御力(DEF): 2500
#   闪避率(EVA): 0.45
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: sage (等级 3)
# ------------------------------------------------------------
# 【公式预期】: -114.6892
# 【模拟均值】: -114.6250
# 【误差分析】: 绝对误差 0.0642 / 相对误差 0.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : -114.6250
# 中位数 (Median) : -100.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : -500.0000
# 标准差 (Std Dev): 93.6515
# ------------------------------

# %% [markdown]
# # 勇者之证测试

# %%
# ====== 勇者之证 1级 测试 ======
run_test_case(
    title="勇者1级-普通怪物",
    description="勇者1级：无特殊效果。测试基础数值。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-坚固怪物(Solid)",
    description="勇者1级 + 坚固：无攻击增益，防御压力大。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-仿攻怪物(Mimic)",
    description="勇者1级 + 仿攻：没有攻击加成，容易被反伤。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-K连击(k=2)",
    description="勇者1级 + 连击(k=2)：无加成，伤害压力大。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 2,
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

run_test_case(
    title="勇者1级-魔攻怪物(Magic)",
    description="勇者1级 vs 魔攻：无特殊对抗能力。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 1
    }
)

# ====== 勇者之证 2级 测试 ======
run_test_case(
    title="勇者2级-普通怪物",
    description="勇者2级：每回合2次攻击。伤害输出翻倍。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-坚固怪物(Solid)",
    description="勇者2级 + 坚固：2次攻击可能击穿或触发暴击。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-仿攻怪物(Mimic)",
    description="勇者2级 + 仿攻：2次高伤害输出对阵反伤。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-K连击(k=3)",
    description="勇者2级 + 连击(k=3)：2次vs 3次，频率竞争。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 3,
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

run_test_case(
    title="勇者2级-魔攻怪物(Magic)",
    description="勇者2级 vs 魔攻：2次攻击应对魔攻伤害。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 2
    }
)

# ====== 勇者之证 3级 测试 ======
run_test_case(
    title="勇者3级-普通怪物",
    description="勇者3级：每回合2次攻击+16%额外伤害。最强输出。",
    sim_params={
        'm_hp': 1000, 'm_atk': 300, 'm_def': 150, 'm_eva': 0.1, 'm_crit': 0.1,
        'h_atk': 450, 'h_def': 180, 'h_eva': 0.05, 'h_crit': 0.2,
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-坚固怪物(Solid)",
    description="勇者3级 + 坚固：额外伤害加成可能突破坚固防御。",
    sim_params={
        'm_hp': 1200, 'm_atk': 350, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 500, 'h_def': 200, 'h_eva': 0.05, 'h_crit': 0.15,
        'special_type': 'solid',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-仿攻怪物(Mimic)",
    description="勇者3级 + 仿攻：2次高伤害+加成vs反伤，输出优势明显。",
    sim_params={
        'm_hp': 800, 'm_atk': 150, 'm_def': 200, 'm_eva': 0, 'm_crit': 0,
        'h_atk': 800, 'h_def': 220, 'h_eva': 0, 'h_crit': 0.1,
        'special_type': 'mimic',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-K连击(k=4)",
    description="勇者3级 + 连击(k=4)：2次高伤害+加成vs 4次连击。",
    sim_params={
        'm_hp': 1500, 'm_atk': 250, 'm_def': 100, 'm_eva': 0.05, 'm_crit': 0.15,
        'h_atk': 450, 'h_def': 150, 'h_eva': 0.05, 'h_crit': 0.18,
        'special_type': 'k_combo', 'k_value': 4,
        'emblem_type': 'hero', 'emblem_level': 3
    }
)

run_test_case(
    title="勇者3级-魔攻怪物(Magic)",
    description="勇者3级 vs 魔攻：2次攻击+加成应对无视防御伤害。",
    sim_params={
        'm_hp': 900, 'm_atk': 400, 'm_def': 120, 'm_eva': 0.1, 'm_crit': 0.05,
        'h_atk': 400, 'h_def': 500, 'h_eva': 0.05, 'h_crit': 0.1,
        'special_type': 'magic',
        'emblem_type': 'hero', 'emblem_level': 3
    }
)
# Out:
# ============================================================
# 测试案例: 勇者1级-普通怪物
# 描述: 勇者1级：无特殊效果。测试基础数值。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 358.3653
# 【模拟均值】: 358.1640
# 【误差分析】: 绝对误差 0.2013 / 相对误差 0.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 358.1640
# 中位数 (Median) : 360.0000
# 最大值 (Max)    : 1200.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 137.9095
# ------------------------------
# ============================================================
# 测试案例: 勇者1级-坚固怪物(Solid)
# 描述: 勇者1级 + 坚固：无攻击增益，防御压力大。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 179855.6902
# 【模拟均值】: 179847.2700
# 【误差分析】: 绝对误差 8.4202 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 179847.2700
# 中位数 (Median) : 179850.0000
# 最大值 (Max)    : 191250.0000
# 最小值 (Min)    : 168450.0000
# 标准差 (Std Dev): 3000.5507
# ------------------------------
# ============================================================
# 测试案例: 勇者1级-仿攻怪物(Mimic)
# 描述: 勇者1级 + 仿攻：没有攻击加成，容易被反伤。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 522.0000
# 【模拟均值】: 521.1300
# 【误差分析】: 绝对误差 0.8700 / 相对误差 0.17%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 521.1300
# 中位数 (Median) : 580.0000
# 最大值 (Max)    : 580.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 175.1540
# ------------------------------
# ============================================================
# 测试案例: 勇者1级-K连击(k=2)
# 描述: 勇者1级 + 连击(k=2)：无加成，伤害压力大。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 2
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 785.8147
# 【模拟均值】: 785.3700
# 【误差分析】: 绝对误差 0.4447 / 相对误差 0.06%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 785.3700
# 中位数 (Median) : 800.0000
# 最大值 (Max)    : 2100.0000
# 最小值 (Min)    : 200.0000
# 标准差 (Std Dev): 215.4785
# ------------------------------
# ============================================================
# 测试案例: 勇者1级-魔攻怪物(Magic)
# 描述: 勇者1级 vs 魔攻：无特殊对抗能力。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 1)
# ------------------------------------------------------------
# 【公式预期】: 1249.7567
# 【模拟均值】: 1248.8800
# 【误差分析】: 绝对误差 0.8767 / 相对误差 0.07%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 1248.8800
# 中位数 (Median) : 1200.0000
# 最大值 (Max)    : 3600.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 405.5746
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-普通怪物
# 描述: 勇者2级：每回合2次攻击。伤害输出翻倍。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 147.4927
# 【模拟均值】: 147.1140
# 【误差分析】: 绝对误差 0.3787 / 相对误差 0.26%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 147.1140
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 720.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 77.5832
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-坚固怪物(Solid)
# 描述: 勇者2级 + 坚固：2次攻击可能击穿或触发暴击。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 89886.8764
# 【模拟均值】: 89894.0250
# 【误差分析】: 绝对误差 7.1486 / 相对误差 0.01%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 89894.0250
# 中位数 (Median) : 89850.0000
# 最大值 (Max)    : 97500.0000
# 最小值 (Min)    : 83250.0000
# 标准差 (Std Dev): 1834.5378
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-仿攻怪物(Mimic)
# 描述: 勇者2级 + 仿攻：2次高伤害输出对阵反伤。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 0.0000
# 【模拟均值】: 0.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 nan%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 0.0000
# 中位数 (Median) : 0.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-K连击(k=3)
# 描述: 勇者2级 + 连击(k=3)：2次vs 3次，频率竞争。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 3
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 509.6890
# 【模拟均值】: 508.1000
# 【误差分析】: 绝对误差 1.5890 / 相对误差 0.31%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 508.1000
# 中位数 (Median) : 500.0000
# 最大值 (Max)    : 1500.0000
# 最小值 (Min)    : 100.0000
# 标准差 (Std Dev): 196.6352
# ------------------------------
# ============================================================
# 测试案例: 勇者2级-魔攻怪物(Magic)
# 描述: 勇者2级 vs 魔攻：2次攻击应对魔攻伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 2)
# ------------------------------------------------------------
# 【公式预期】: 506.1334
# 【模拟均值】: 503.0600
# 【误差分析】: 绝对误差 3.0734 / 相对误差 0.61%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 503.0600
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 2000.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 241.0864
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-普通怪物
# 描述: 勇者3级：每回合2次攻击+16%额外伤害。最强输出。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1000
#   攻击力(ATK): 300
#   防御力(DEF): 150
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.1
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 180
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.2
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: None
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 146.5288
# 【模拟均值】: 146.6460
# 【误差分析】: 绝对误差 0.1172 / 相对误差 0.08%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 146.6460
# 中位数 (Median) : 120.0000
# 最大值 (Max)    : 720.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 79.2040
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-坚固怪物(Solid)
# 描述: 勇者3级 + 坚固：额外伤害加成可能突破坚固防御。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1200
#   攻击力(ATK): 350
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 500
#   防御力(DEF): 200
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: solid
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 89886.8764
# 【模拟均值】: 89884.8825
# 【误差分析】: 绝对误差 1.9939 / 相对误差 0.00%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 89884.8825
# 中位数 (Median) : 89850.0000
# 最大值 (Max)    : 97650.0000
# 最小值 (Min)    : 82650.0000
# 标准差 (Std Dev): 1848.2366
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-仿攻怪物(Mimic)
# 描述: 勇者3级 + 仿攻：2次高伤害+加成vs反伤，输出优势明显。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 800
#   攻击力(ATK): 150
#   防御力(DEF): 200
#   闪避率(EVA): 0
#   暴击率(CRIT): 0
# 【勇士属性】
#   攻击力(ATK): 800
#   防御力(DEF): 220
#   闪避率(EVA): 0
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: mimic
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 0.0000
# 【模拟均值】: 0.0000
# 【误差分析】: 绝对误差 0.0000 / 相对误差 nan%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 0.0000
# 中位数 (Median) : 0.0000
# 最大值 (Max)    : 0.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 0.0000
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-K连击(k=4)
# 描述: 勇者3级 + 连击(k=4)：2次高伤害+加成vs 4次连击。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1500
#   攻击力(ATK): 250
#   防御力(DEF): 100
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 450
#   防御力(DEF): 150
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.18
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: k_combo
#   连击次数: 4
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 675.5472
# 【模拟均值】: 676.3100
# 【误差分析】: 绝对误差 0.7628 / 相对误差 0.11%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 676.3100
# 中位数 (Median) : 700.0000
# 最大值 (Max)    : 1900.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 254.7720
# ------------------------------
# ============================================================
# 测试案例: 勇者3级-魔攻怪物(Magic)
# 描述: 勇者3级 vs 魔攻：2次攻击+加成应对无视防御伤害。
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 900
#   攻击力(ATK): 400
#   防御力(DEF): 120
#   闪避率(EVA): 0.1
#   暴击率(CRIT): 0.05
# 【勇士属性】
#   攻击力(ATK): 400
#   防御力(DEF): 500
#   闪避率(EVA): 0.05
#   暴击率(CRIT): 0.1
# 【临界值】: 攻击 0, 防御 0
# 【特殊能力】: magic
# 【徽章类型】: hero (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 506.1334
# 【模拟均值】: 508.9800
# 【误差分析】: 绝对误差 2.8466 / 相对误差 0.56%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 20000
# 平均值 (Mean)   : 508.9800
# 中位数 (Median) : 400.0000
# 最大值 (Max)    : 2000.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 240.7724
# ------------------------------

# %% [markdown]
# # 随便测试

# %%
run_test_case(
    title="随便测试",
    description="随便测试",
    sim_params={
        'm_hp': 1412, 'm_atk': 623, 'm_def': 224, 'm_eva': 0.14, 'm_crit': 0.15,
        'h_atk': 424, 'h_def': 240, 'h_eva': 0.23, 'h_crit': 0.16,'h_atk_thresh': 5,'h_def_thresh':2,
        'emblem_type': None, 'emblem_level': 3,
        'abnormal_prob':0.2
    },
    n_trials=100000
)
# Out:
# ============================================================
# 测试案例: 随便测试
# 描述: 随便测试
# ------------------------------------------------------------
# 【怪物属性】
#   生命值(HP): 1412
#   攻击力(ATK): 623
#   防御力(DEF): 224
#   闪避率(EVA): 0.14
#   暴击率(CRIT): 0.15
# 【勇士属性】
#   攻击力(ATK): 424
#   防御力(DEF): 240
#   闪避率(EVA): 0.23
#   暴击率(CRIT): 0.16
# 【临界值】: 攻击 5, 防御 2
# 【特殊能力】: None
# 【徽章类型】: None (等级 3)
# ------------------------------------------------------------
# 【公式预期】: 2427.4441
# 【模拟均值】: 2429.2005
# 【误差分析】: 绝对误差 1.7564 / 相对误差 0.07%
# ------------------------------
# 【蒙特卡洛模拟统计结果】
# 模拟次数 (Count) : 100000
# 平均值 (Mean)   : 2429.2005
# 中位数 (Median) : 2298.0000
# 最大值 (Max)    : 6894.0000
# 最小值 (Min)    : 0.0000
# 标准差 (Std Dev): 775.2844
# ------------------------------
